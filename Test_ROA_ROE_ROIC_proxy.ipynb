# %% [markdown]
# #### Return on Assets

# %%
# sp500_roa_power_fixed.py

import yfinance as yf
import pandas as pd
import numpy as np
import time
import requests
from io import StringIO

# 1) Get S&P500 list from Wikipedia (with headers to avoid 403)
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}
response = requests.get(url, headers=headers)
if response.status_code != 200:
    raise Exception(f"Failed to fetch S&P 500 list. HTTP {response.status_code}")

sp500 = pd.read_html(StringIO(response.text))[0]
sp500.columns = [c.strip() for c in sp500.columns]
sp500 = sp500.rename(columns={"Symbol": "Ticker", "Security": "Full Name"})

# 2) Helper to find the right row label
def find_label(labels, candidates):
    for cand in candidates:
        mask = labels.str.contains(cand, case=False, na=False)
        if mask.any():
            return labels[mask].index[0]
    return None

# 3) Function to compute ROA Power
def collect_roa_power(ticker, n_years=5):
    try:
        t = yf.Ticker(ticker)
        fin = t.financials
        bs = t.balance_sheet
        if fin is None or fin.empty or bs is None or bs.empty:
            return None

        ni_label = find_label(fin.index.to_series(), ["net income", "netearn", "netprofit"])
        ta_label = find_label(bs.index.to_series(), ["total assets"])
        if ni_label is None or ta_label is None:
            return None

        ni = fin.loc[ni_label]
        ta = bs.loc[ta_label]

        # Compute ROA history
        roa = []
        for date in ni.index:
            n, a = ni.get(date), ta.get(date)
            if pd.notna(n) and pd.notna(a) and a != 0:
                roa.append(n / a)
            if len(roa) >= n_years:
                break

        if len(roa) < 2:
            return None

        # Compute year-to-year changes & power
        changes = np.diff(roa)
        sd = np.std(changes, ddof=0)
        power = float('inf') if sd == 0 else 1.0 / sd

        return {
            "Ticker": ticker,
            "Full Name": t.info.get("longName", np.nan),
            "ROA History": roa,
            "ROA Changes": changes.tolist(),
            "ROA Power": power
        }

    except Exception as e:
        print(f"Error processing {ticker}: {e}")
        return None

# 4) Collect data for all tickers
results = []
for i, row in sp500.iterrows():
    ticker = row["Ticker"]
    rec = collect_roa_power(ticker)
    if rec:
        results.append(rec)
    print(f"[{i+1}/{len(sp500)}] Done: {ticker}")
    time.sleep(1)  # delay to avoid rate limit

# 5) Save and display
df = pd.DataFrame(results).set_index("Ticker")
print(df[["Full Name", "ROA Power"]])
df.to_csv("sp500_roa_power.csv", index=True)
print("\nSaved to sp500_roa_power.csv ✅")
# Out:
# [1/503] Done: MMM
# [2/503] Done: AOS
# [3/503] Done: ABT
# [4/503] Done: ABBV
# [5/503] Done: ACN
# [6/503] Done: ADBE
# [7/503] Done: AMD
# [8/503] Done: AES
# [9/503] Done: AFL
# [10/503] Done: A
# [11/503] Done: APD
# [12/503] Done: ABNB
# [13/503] Done: AKAM
# [14/503] Done: ALB
# [15/503] Done: ARE
# [16/503] Done: ALGN
# [17/503] Done: ALLE
# [18/503] Done: LNT
# [19/503] Done: ALL
# [20/503] Done: GOOGL
# [21/503] Done: GOOG
# [22/503] Done: MO
# [23/503] Done: AMZN
# [24/503] Done: AMCR
# [25/503] Done: AEE
# [26/503] Done: AEP
# [27/503] Done: AXP
# [28/503] Done: AIG
# [29/503] Done: AMT
# [30/503] Done: AWK
# [31/503] Done: AMP
# [32/503] Done: AME
# [33/503] Done: AMGN
# [34/503] Done: APH
# [35/503] Done: ADI
# [36/503] Done: AON
# [37/503] Done: APA
# [38/503] Done: APO
# [39/503] Done: AAPL
# [40/503] Done: AMAT
# [41/503] Done: APP
# [42/503] Done: APTV
# [43/503] Done: ACGL
# [44/503] Done: ADM
# [45/503] Done: ANET
# [46/503] Done: AJG
# [47/503] Done: AIZ
# [48/503] Done: T
# [49/503] Done: ATO
# [50/503] Done: ADSK
# [51/503] Done: ADP
# [52/503] Done: AZO
# [53/503] Done: AVB
# [54/503] Done: AVY
# [55/503] Done: AXON
# [56/503] Done: BKR
# [57/503] Done: BALL
# [58/503] Done: BAC
# [59/503] Done: BAX
# [60/503] Done: BDX
# [61/503] Done: BRK.B
# [62/503] Done: BBY
# [63/503] Done: TECH
# [64/503] Done: BIIB
# [65/503] Done: BLK
# [66/503] Done: BX
# [67/503] Done: XYZ
# [68/503] Done: BK
# [69/503] Done: BA
# [70/503] Done: BKNG
# [71/503] Done: BSX
# [72/503] Done: BMY
# [73/503] Done: AVGO
# [74/503] Done: BR
# [75/503] Done: BRO
# [76/503] Done: BF.B
# [77/503] Done: BLDR
# [78/503] Done: BG
# [79/503] Done: BXP
# [80/503] Done: CHRW
# [81/503] Done: CDNS
# [82/503] Done: CPT
# [83/503] Done: CPB
# [84/503] Done: COF
# [85/503] Done: CAH
# [86/503] Done: KMX
# [87/503] Done: CCL
# [88/503] Done: CARR
# [89/503] Done: CAT
# [90/503] Done: CBOE
# [91/503] Done: CBRE
# [92/503] Done: CDW
# [93/503] Done: COR
# [94/503] Done: CNC
# [95/503] Done: CNP
# [96/503] Done: CF
# [97/503] Done: CRL
# [98/503] Done: SCHW
# [99/503] Done: CHTR
# [100/503] Done: CVX
# [101/503] Done: CMG
# [102/503] Done: CB
# [103/503] Done: CHD
# [104/503] Done: CI
# [105/503] Done: CINF
# [106/503] Done: CTAS
# [107/503] Done: CSCO
# [108/503] Done: C
# [109/503] Done: CFG
# [110/503] Done: CLX
# [111/503] Done: CME
# [112/503] Done: CMS
# [113/503] Done: KO
# [114/503] Done: CTSH
# [115/503] Done: COIN
# [116/503] Done: CL
# [117/503] Done: CMCSA
# [118/503] Done: CAG
# [119/503] Done: COP
# [120/503] Done: ED
# [121/503] Done: STZ
# [122/503] Done: CEG
# [123/503] Done: COO
# [124/503] Done: CPRT
# [125/503] Done: GLW
# [126/503] Done: CPAY
# [127/503] Done: CTVA
# [128/503] Done: CSGP
# [129/503] Done: COST
# [130/503] Done: CTRA
# [131/503] Done: CRWD
# [132/503] Done: CCI
# [133/503] Done: CSX
# [134/503] Done: CMI
# [135/503] Done: CVS
# [136/503] Done: DHR
# [137/503] Done: DRI
# [138/503] Done: DDOG
# [139/503] Done: DVA
# [140/503] Done: DAY
# [141/503] Done: DECK
# [142/503] Done: DE
# [143/503] Done: DELL
# [144/503] Done: DAL
# [145/503] Done: DVN
# [146/503] Done: DXCM
# [147/503] Done: FANG
# [148/503] Done: DLR
# [149/503] Done: DG
# [150/503] Done: DLTR
# [151/503] Done: D
# [152/503] Done: DPZ
# [153/503] Done: DASH
# [154/503] Done: DOV
# [155/503] Done: DOW
# [156/503] Done: DHI
# [157/503] Done: DTE
# [158/503] Done: DUK
# [159/503] Done: DD
# [160/503] Done: EMN
# [161/503] Done: ETN
# [162/503] Done: EBAY
# [163/503] Done: ECL
# [164/503] Done: EIX
# [165/503] Done: EW
# [166/503] Done: EA
# [167/503] Done: ELV
# [168/503] Done: EME
# [169/503] Done: EMR
# [170/503] Done: ETR
# [171/503] Done: EOG
# [172/503] Done: EPAM
# [173/503] Done: EQT
# [174/503] Done: EFX
# [175/503] Done: EQIX
# [176/503] Done: EQR
# [177/503] Done: ERIE
# [178/503] Done: ESS
# [179/503] Done: EL
# [180/503] Done: EG
# [181/503] Done: EVRG
# [182/503] Done: ES
# [183/503] Done: EXC
# [184/503] Done: EXE
# [185/503] Done: EXPE
# [186/503] Done: EXPD
# [187/503] Done: EXR
# [188/503] Done: XOM
# [189/503] Done: FFIV
# [190/503] Done: FDS
# [191/503] Done: FICO
# [192/503] Done: FAST
# [193/503] Done: FRT
# [194/503] Done: FDX
# [195/503] Done: FIS
# [196/503] Done: FITB
# [197/503] Done: FSLR
# [198/503] Done: FE
# [199/503] Done: FI
# [200/503] Done: F
# [201/503] Done: FTNT
# [202/503] Done: FTV
# [203/503] Done: FOXA
# [204/503] Done: FOX
# [205/503] Done: BEN
# [206/503] Done: FCX
# [207/503] Done: GRMN
# [208/503] Done: IT
# [209/503] Done: GE
# [210/503] Done: GEHC
# [211/503] Done: GEV
# [212/503] Done: GEN
# [213/503] Done: GNRC
# [214/503] Done: GD
# [215/503] Done: GIS
# [216/503] Done: GM
# [217/503] Done: GPC
# [218/503] Done: GILD
# [219/503] Done: GPN
# [220/503] Done: GL
# [221/503] Done: GDDY
# [222/503] Done: GS
# [223/503] Done: HAL
# [224/503] Done: HIG
# [225/503] Done: HAS
# [226/503] Done: HCA
# [227/503] Done: DOC
# [228/503] Done: HSIC
# [229/503] Done: HSY
# [230/503] Done: HPE
# [231/503] Done: HLT
# [232/503] Done: HOLX
# [233/503] Done: HD
# [234/503] Done: HON
# [235/503] Done: HRL
# [236/503] Done: HST
# [237/503] Done: HWM
# [238/503] Done: HPQ
# [239/503] Done: HUBB
# [240/503] Done: HUM
# [241/503] Done: HBAN
# [242/503] Done: HII
# [243/503] Done: IBM
# [244/503] Done: IEX
# [245/503] Done: IDXX
# [246/503] Done: ITW
# [247/503] Done: INCY
# [248/503] Done: IR
# [249/503] Done: PODD
# [250/503] Done: INTC
# [251/503] Done: IBKR
# [252/503] Done: ICE
# [253/503] Done: IFF
# [254/503] Done: IP
# [255/503] Done: IPG
# [256/503] Done: INTU
# [257/503] Done: ISRG
# [258/503] Done: IVZ
# [259/503] Done: INVH
# [260/503] Done: IQV
# [261/503] Done: IRM
# [262/503] Done: JBHT
# [263/503] Done: JBL
# [264/503] Done: JKHY
# [265/503] Done: J
# [266/503] Done: JNJ
# [267/503] Done: JCI
# [268/503] Done: JPM
# [269/503] Done: K
# [270/503] Done: KVUE
# [271/503] Done: KDP
# [272/503] Done: KEY
# [273/503] Done: KEYS
# [274/503] Done: KMB
# [275/503] Done: KIM
# [276/503] Done: KMI
# [277/503] Done: KKR
# [278/503] Done: KLAC
# [279/503] Done: KHC
# [280/503] Done: KR
# [281/503] Done: LHX
# [282/503] Done: LH
# [283/503] Done: LRCX
# [284/503] Done: LW
# [285/503] Done: LVS
# [286/503] Done: LDOS
# [287/503] Done: LEN
# [288/503] Done: LII
# [289/503] Done: LLY
# [290/503] Done: LIN
# [291/503] Done: LYV
# [292/503] Done: LKQ
# [293/503] Done: LMT
# [294/503] Done: L
# [295/503] Done: LOW
# [296/503] Done: LULU
# [297/503] Done: LYB
# [298/503] Done: MTB
# [299/503] Done: MPC
# [300/503] Done: MAR
# [301/503] Done: MMC
# [302/503] Done: MLM
# [303/503] Done: MAS
# [304/503] Done: MA
# [305/503] Done: MTCH
# [306/503] Done: MKC
# [307/503] Done: MCD
# [308/503] Done: MCK
# [309/503] Done: MDT
# [310/503] Done: MRK
# [311/503] Done: META
# [312/503] Done: MET
# [313/503] Done: MTD
# [314/503] Done: MGM
# [315/503] Done: MCHP
# [316/503] Done: MU
# [317/503] Done: MSFT
# [318/503] Done: MAA
# [319/503] Done: MRNA
# [320/503] Done: MHK
# [321/503] Done: MOH
# [322/503] Done: TAP
# [323/503] Done: MDLZ
# [324/503] Done: MPWR
# [325/503] Done: MNST
# [326/503] Done: MCO
# [327/503] Done: MS
# [328/503] Done: MOS
# [329/503] Done: MSI
# [330/503] Done: MSCI
# [331/503] Done: NDAQ
# [332/503] Done: NTAP
# [333/503] Done: NFLX
# [334/503] Done: NEM
# [335/503] Done: NWSA
# [336/503] Done: NWS
# [337/503] Done: NEE
# [338/503] Done: NKE
# [339/503] Done: NI
# [340/503] Done: NDSN
# [341/503] Done: NSC
# [342/503] Done: NTRS
# [343/503] Done: NOC
# [344/503] Done: NCLH
# [345/503] Done: NRG
# [346/503] Done: NUE
# [347/503] Done: NVDA
# [348/503] Done: NVR
# [349/503] Done: NXPI
# [350/503] Done: ORLY
# [351/503] Done: OXY
# [352/503] Done: ODFL
# [353/503] Done: OMC
# [354/503] Done: ON
# [355/503] Done: OKE
# [356/503] Done: ORCL
# [357/503] Done: OTIS
# [358/503] Done: PCAR
# [359/503] Done: PKG
# [360/503] Done: PLTR
# [361/503] Done: PANW
# [362/503] Done: PSKY
# [363/503] Done: PH
# [364/503] Done: PAYX
# [365/503] Done: PAYC
# [366/503] Done: PYPL
# [367/503] Done: PNR
# [368/503] Done: PEP
# [369/503] Done: PFE
# [370/503] Done: PCG
# [371/503] Done: PM
# [372/503] Done: PSX
# [373/503] Done: PNW
# [374/503] Done: PNC
# [375/503] Done: POOL
# [376/503] Done: PPG
# [377/503] Done: PPL
# [378/503] Done: PFG
# [379/503] Done: PG
# [380/503] Done: PGR
# [381/503] Done: PLD
# [382/503] Done: PRU
# [383/503] Done: PEG
# [384/503] Done: PTC
# [385/503] Done: PSA
# [386/503] Done: PHM
# [387/503] Done: PWR
# [388/503] Done: QCOM
# [389/503] Done: DGX
# [390/503] Done: RL
# [391/503] Done: RJF
# [392/503] Done: RTX
# [393/503] Done: O
# [394/503] Done: REG
# [395/503] Done: REGN
# [396/503] Done: RF
# [397/503] Done: RSG
# [398/503] Done: RMD
# [399/503] Done: RVTY
# [400/503] Done: HOOD
# [401/503] Done: ROK
# [402/503] Done: ROL
# [403/503] Done: ROP
# [404/503] Done: ROST
# [405/503] Done: RCL
# [406/503] Done: SPGI
# [407/503] Done: CRM
# [408/503] Done: SBAC
# [409/503] Done: SLB
# [410/503] Done: STX
# [411/503] Done: SRE
# [412/503] Done: NOW
# [413/503] Done: SHW
# [414/503] Done: SPG
# [415/503] Done: SWKS
# [416/503] Done: SJM
# [417/503] Done: SW
# [418/503] Done: SNA
# [419/503] Done: SOLV
# [420/503] Done: SO
# [421/503] Done: LUV
# [422/503] Done: SWK
# [423/503] Done: SBUX
# [424/503] Done: STT
# [425/503] Done: STLD
# [426/503] Done: STE
# [427/503] Done: SYK
# [428/503] Done: SMCI
# [429/503] Done: SYF
# [430/503] Done: SNPS
# [431/503] Done: SYY
# [432/503] Done: TMUS
# [433/503] Done: TROW
# [434/503] Done: TTWO
# [435/503] Done: TPR
# [436/503] Done: TRGP
# [437/503] Done: TGT
# [438/503] Done: TEL
# [439/503] Done: TDY
# [440/503] Done: TER
# [441/503] Done: TSLA
# [442/503] Done: TXN
# [443/503] Done: TPL
# [444/503] Done: TXT
# [445/503] Done: TMO
# [446/503] Done: TJX
# [447/503] Done: TKO
# [448/503] Done: TTD
# [449/503] Done: TSCO
# [450/503] Done: TT
# [451/503] Done: TDG
# [452/503] Done: TRV
# [453/503] Done: TRMB
# [454/503] Done: TFC
# [455/503] Done: TYL
# [456/503] Done: TSN
# [457/503] Done: USB
# [458/503] Done: UBER
# [459/503] Done: UDR
# [460/503] Done: ULTA
# [461/503] Done: UNP
# [462/503] Done: UAL
# [463/503] Done: UPS
# [464/503] Done: URI
# [465/503] Done: UNH
# [466/503] Done: UHS
# [467/503] Done: VLO
# [468/503] Done: VTR
# [469/503] Done: VLTO
# [470/503] Done: VRSN
# [471/503] Done: VRSK
# [472/503] Done: VZ
# [473/503] Done: VRTX
# [474/503] Done: VTRS
# [475/503] Done: VICI
# [476/503] Done: V
# [477/503] Done: VST
# [478/503] Done: VMC
# [479/503] Done: WRB
# [480/503] Done: GWW
# [481/503] Done: WAB
# [482/503] Done: WMT
# [483/503] Done: DIS
# [484/503] Done: WBD
# [485/503] Done: WM
# [486/503] Done: WAT
# [487/503] Done: WEC
# [488/503] Done: WFC
# [489/503] Done: WELL
# [490/503] Done: WST
# [491/503] Done: WDC
# [492/503] Done: WY
# [493/503] Done: WSM
# [494/503] Done: WMB
# [495/503] Done: WTW
# [496/503] Done: WDAY
# [497/503] Done: WYNN
# [498/503] Done: XEL
# [499/503] Done: XYL
# [500/503] Done: YUM
# [501/503] Done: ZBRA
# [502/503] Done: ZBH
# [503/503] Done: ZTS
#                              Full Name   ROA Power
# Ticker
# MMM                         3M Company    4.395508
# AOS            A. O. Smith Corporation   14.051464
# ABT                Abbott Laboratories   22.291185
# ABBV                       AbbVie Inc.   41.524901
# ACN                      Accenture plc  120.178953
# ...                                ...         ...
# XYL                         Xylem Inc.   91.979022
# YUM                  Yum! Brands, Inc.   32.120891
# ZBRA    Zebra Technologies Corporation   24.747478
# ZBH       Zimmer Biomet Holdings, Inc.   54.221435
# ZTS                        Zoetis Inc.   89.341980
#
# [501 rows x 2 columns]
#
# Saved to sp500_roa_power.csv ✅

# %%
#ROA = pd.read_csv("sp500_roa_power.csv", index_col=0)
#print(ROA.sort_values(by="ROA", ascending=False))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19428\2495062281.py in ?()
#       1 ROA = pd.read_csv("sp500_roa_power.csv", index_col=0)
# ----> 2 print(ROA.sort_values(by="ROA", ascending=False))
#
# c:\Users\Lfran\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7172             )
#    7173         elif len(by):
#    7174             # len(by) == 1
#    7175
# -> 7176             k = self._get_label_or_level_values(by[0], axis=axis)
#    7177
#    7178             # need to rewrap column in Series to apply key function
#    7179             if key is not None:
#
# c:\Users\Lfran\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1906             values = self.xs(key, axis=other_axes[0])._values
#    1907         elif self._is_level_reference(key, axis=axis):
#    1908             values = self.axes[axis].get_level_values(key)._values
#    1909         else:
# -> 1910             raise KeyError(key)
#    1911
#    1912         # Check for duplicates
#    1913         if values.ndim > 1:
#
# KeyError: 'ROA'

# %% [markdown]
# ### Return on Equity

# %%
# sp500_roe_power_fixed.py

import yfinance as yf
import pandas as pd
import numpy as np
import time
import requests
from io import StringIO

# 1) Get S&P500 list from Wikipedia (avoid 403 error)
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}

response = requests.get(url, headers=headers)
if response.status_code != 200:
    raise Exception(f"Failed to fetch S&P 500 list. HTTP {response.status_code}")

sp500 = pd.read_html(StringIO(response.text))[0]
sp500.columns = [c.strip() for c in sp500.columns]
sp500 = sp500.rename(columns={"Symbol": "Ticker", "Security": "Full Name"})

# 2) Helper to find correct row label
def find_label(labels, candidates):
    for cand in candidates:
        mask = labels.str.contains(cand, case=False, na=False)
        if mask.any():
            return labels[mask].index[0]
    return None

# 3) Compute ROE Power
def collect_roe_power(ticker, n_years=5):
    try:
        t = yf.Ticker(ticker)
        fin = t.financials
        bs = t.balance_sheet

        if fin is None or fin.empty or bs is None or bs.empty:
            return None

        # Identify labels
        ni_label = find_label(fin.index.to_series(), ["net income", "netearn", "netprofit"])
        eq_label = find_label(bs.index.to_series(), ["stockholders equity", "total equity", "shareholders equity"])
        if ni_label is None or eq_label is None:
            return None

        ni = fin.loc[ni_label]
        eq = bs.loc[eq_label]

        # Build ROE history
        roe = []
        for date in ni.index:
            n, e = ni.get(date), eq.get(date)
            if pd.notna(n) and pd.notna(e) and e != 0:
                roe.append(n / e)
            if len(roe) >= n_years:
                break

        if len(roe) < 2:
            return None

        # Compute changes and power
        changes = np.diff(roe)
        sd = np.std(changes, ddof=0)
        power = float('inf') if sd == 0 else 1.0 / sd

        return {
            "Ticker": ticker,
            "Full Name": t.info.get("longName", np.nan),
            "ROE History": roe,
            "ROE Changes": changes.tolist(),
            "ROE Power": power
        }

    except Exception as e:
        print(f"Error processing {ticker}: {e}")
        return None

# 4) Loop through S&P 500 list
results = []
for i, row in sp500.iterrows():
    ticker = row["Ticker"]
    rec = collect_roe_power(ticker)
    if rec:
        results.append(rec)
    print(f"[{i+1}/{len(sp500)}] Done: {ticker}")
    time.sleep(1)  # avoid throttling from Yahoo

# 5) Save results
ROE = pd.DataFrame(results).set_index("Ticker")
print(ROE[["Full Name", "ROE Power"]])
ROE.to_csv("sp500_roe_power.csv", index=True)
print("\nSaved to sp500_roe_power.csv ✅")
# Out:
# [1/503] Done: MMM
# [2/503] Done: AOS
# [3/503] Done: ABT
# [4/503] Done: ABBV
# [5/503] Done: ACN
# [6/503] Done: ADBE
# [7/503] Done: AMD
# [8/503] Done: AES
# [9/503] Done: AFL
# [10/503] Done: A
# [11/503] Done: APD
# [12/503] Done: ABNB
# [13/503] Done: AKAM
# [14/503] Done: ALB
# [15/503] Done: ARE
# [16/503] Done: ALGN
# [17/503] Done: ALLE
# [18/503] Done: LNT
# [19/503] Done: ALL
# [20/503] Done: GOOGL
# [21/503] Done: GOOG
# [22/503] Done: MO
# [23/503] Done: AMZN
# [24/503] Done: AMCR
# [25/503] Done: AEE
# [26/503] Done: AEP
# [27/503] Done: AXP
# [28/503] Done: AIG
# [29/503] Done: AMT
# [30/503] Done: AWK
# [31/503] Done: AMP
# [32/503] Done: AME
# [33/503] Done: AMGN
# [34/503] Done: APH
# [35/503] Done: ADI
# [36/503] Done: AON
# [37/503] Done: APA
# [38/503] Done: APO
# [39/503] Done: AAPL
# [40/503] Done: AMAT
# [41/503] Done: APP
# [42/503] Done: APTV
# [43/503] Done: ACGL
# [44/503] Done: ADM
# [45/503] Done: ANET
# [46/503] Done: AJG
# [47/503] Done: AIZ
# [48/503] Done: T
# [49/503] Done: ATO
# [50/503] Done: ADSK
# [51/503] Done: ADP
# [52/503] Done: AZO
# [53/503] Done: AVB
# [54/503] Done: AVY
# [55/503] Done: AXON
# [56/503] Done: BKR
# [57/503] Done: BALL
# [58/503] Done: BAC
# [59/503] Done: BAX
# [60/503] Done: BDX
# [61/503] Done: BRK.B
# [62/503] Done: BBY
# [63/503] Done: TECH
# [64/503] Done: BIIB
# [65/503] Done: BLK
# [66/503] Done: BX
# [67/503] Done: XYZ
# [68/503] Done: BK
# [69/503] Done: BA
# [70/503] Done: BKNG
# [71/503] Done: BSX
# [72/503] Done: BMY
# [73/503] Done: AVGO
# [74/503] Done: BR
# [75/503] Done: BRO
# [76/503] Done: BF.B
# [77/503] Done: BLDR
# [78/503] Done: BG
# [79/503] Done: BXP
# [80/503] Done: CHRW
# [81/503] Done: CDNS
# [82/503] Done: CPT
# [83/503] Done: CPB
# [84/503] Done: COF
# [85/503] Done: CAH
# [86/503] Done: KMX
# [87/503] Done: CCL
# [88/503] Done: CARR
# [89/503] Done: CAT
# [90/503] Done: CBOE
# [91/503] Done: CBRE
# [92/503] Done: CDW
# [93/503] Done: COR
# [94/503] Done: CNC
# [95/503] Done: CNP
# [96/503] Done: CF
# [97/503] Done: CRL
# [98/503] Done: SCHW
# [99/503] Done: CHTR
# [100/503] Done: CVX
# [101/503] Done: CMG
# [102/503] Done: CB
# [103/503] Done: CHD
# [104/503] Done: CI
# [105/503] Done: CINF
# [106/503] Done: CTAS
# [107/503] Done: CSCO
# [108/503] Done: C
# [109/503] Done: CFG
# [110/503] Done: CLX
# [111/503] Done: CME
# [112/503] Done: CMS
# [113/503] Done: KO
# [114/503] Done: CTSH
# [115/503] Done: COIN
# [116/503] Done: CL
# [117/503] Done: CMCSA
# [118/503] Done: CAG
# [119/503] Done: COP
# [120/503] Done: ED
# [121/503] Done: STZ
# [122/503] Done: CEG
# [123/503] Done: COO
# [124/503] Done: CPRT
# [125/503] Done: GLW
# [126/503] Done: CPAY
# [127/503] Done: CTVA
# [128/503] Done: CSGP
# [129/503] Done: COST
# [130/503] Done: CTRA
# [131/503] Done: CRWD
# [132/503] Done: CCI
# [133/503] Done: CSX
# [134/503] Done: CMI
# [135/503] Done: CVS
# [136/503] Done: DHR
# [137/503] Done: DRI
# [138/503] Done: DDOG
# [139/503] Done: DVA
# [140/503] Done: DAY
# [141/503] Done: DECK
# [142/503] Done: DE
# [143/503] Done: DELL
# [144/503] Done: DAL
# [145/503] Done: DVN
# [146/503] Done: DXCM
# [147/503] Done: FANG
# [148/503] Done: DLR
# [149/503] Done: DG
# [150/503] Done: DLTR
# [151/503] Done: D
# [152/503] Done: DPZ
# [153/503] Done: DASH
# [154/503] Done: DOV
# [155/503] Done: DOW
# [156/503] Done: DHI
# [157/503] Done: DTE
# [158/503] Done: DUK
# [159/503] Done: DD
# [160/503] Done: EMN
# [161/503] Done: ETN
# [162/503] Done: EBAY
# [163/503] Done: ECL
# [164/503] Done: EIX
# [165/503] Done: EW
# [166/503] Done: EA
# [167/503] Done: ELV
# [168/503] Done: EME
# [169/503] Done: EMR
# [170/503] Done: ETR
# [171/503] Done: EOG
# [172/503] Done: EPAM
# [173/503] Done: EQT
# [174/503] Done: EFX
# [175/503] Done: EQIX
# [176/503] Done: EQR
# [177/503] Done: ERIE
# [178/503] Done: ESS
# [179/503] Done: EL
# [180/503] Done: EG
# [181/503] Done: EVRG
# [182/503] Done: ES
# [183/503] Done: EXC
# [184/503] Done: EXE
# [185/503] Done: EXPE
# [186/503] Done: EXPD
# [187/503] Done: EXR
# [188/503] Done: XOM
# [189/503] Done: FFIV
# [190/503] Done: FDS
# [191/503] Done: FICO
# [192/503] Done: FAST
# [193/503] Done: FRT
# [194/503] Done: FDX
# [195/503] Done: FIS
# [196/503] Done: FITB
# [197/503] Done: FSLR
# [198/503] Done: FE
# [199/503] Done: FI
# [200/503] Done: F
# [201/503] Done: FTNT
# [202/503] Done: FTV
# [203/503] Done: FOXA
# [204/503] Done: FOX
# [205/503] Done: BEN
# [206/503] Done: FCX
# [207/503] Done: GRMN
# [208/503] Done: IT
# [209/503] Done: GE
# [210/503] Done: GEHC
# [211/503] Done: GEV
# [212/503] Done: GEN
# [213/503] Done: GNRC
# [214/503] Done: GD
# [215/503] Done: GIS
# [216/503] Done: GM
# [217/503] Done: GPC
# [218/503] Done: GILD
# [219/503] Done: GPN
# [220/503] Done: GL
# [221/503] Done: GDDY
# [222/503] Done: GS
# [223/503] Done: HAL
# [224/503] Done: HIG
# [225/503] Done: HAS
# [226/503] Done: HCA
# [227/503] Done: DOC
# [228/503] Done: HSIC
# [229/503] Done: HSY
# [230/503] Done: HPE
# [231/503] Done: HLT
# [232/503] Done: HOLX
# [233/503] Done: HD
# [234/503] Done: HON
# [235/503] Done: HRL
# [236/503] Done: HST
# [237/503] Done: HWM
# [238/503] Done: HPQ
# [239/503] Done: HUBB
# [240/503] Done: HUM
# [241/503] Done: HBAN
# [242/503] Done: HII
# [243/503] Done: IBM
# [244/503] Done: IEX
# [245/503] Done: IDXX
# [246/503] Done: ITW
# [247/503] Done: INCY
# [248/503] Done: IR
# [249/503] Done: PODD
# [250/503] Done: INTC
# [251/503] Done: IBKR
# [252/503] Done: ICE
# [253/503] Done: IFF
# [254/503] Done: IP
# [255/503] Done: IPG
# [256/503] Done: INTU
# [257/503] Done: ISRG
# [258/503] Done: IVZ
# [259/503] Done: INVH
# [260/503] Done: IQV
# [261/503] Done: IRM
# [262/503] Done: JBHT
# [263/503] Done: JBL
# [264/503] Done: JKHY
# [265/503] Done: J
# [266/503] Done: JNJ
# [267/503] Done: JCI
# [268/503] Done: JPM
# [269/503] Done: K
# [270/503] Done: KVUE
# [271/503] Done: KDP
# [272/503] Done: KEY
# [273/503] Done: KEYS
# [274/503] Done: KMB
# [275/503] Done: KIM
# [276/503] Done: KMI
# [277/503] Done: KKR
# [278/503] Done: KLAC
# [279/503] Done: KHC
# [280/503] Done: KR
# [281/503] Done: LHX
# [282/503] Done: LH
# [283/503] Done: LRCX
# [284/503] Done: LW
# [285/503] Done: LVS
# [286/503] Done: LDOS
# [287/503] Done: LEN
# [288/503] Done: LII
# [289/503] Done: LLY
# [290/503] Done: LIN
# [291/503] Done: LYV
# [292/503] Done: LKQ
# [293/503] Done: LMT
# [294/503] Done: L
# [295/503] Done: LOW
# [296/503] Done: LULU
# [297/503] Done: LYB
# [298/503] Done: MTB
# [299/503] Done: MPC
# [300/503] Done: MAR
# [301/503] Done: MMC
# [302/503] Done: MLM
# [303/503] Done: MAS
# [304/503] Done: MA
# [305/503] Done: MTCH
# [306/503] Done: MKC
# [307/503] Done: MCD
# [308/503] Done: MCK
# [309/503] Done: MDT
# [310/503] Done: MRK
# [311/503] Done: META
# [312/503] Done: MET
# [313/503] Done: MTD
# [314/503] Done: MGM
# [315/503] Done: MCHP
# [316/503] Done: MU
# [317/503] Done: MSFT
# [318/503] Done: MAA
# [319/503] Done: MRNA
# [320/503] Done: MHK
# [321/503] Done: MOH
# [322/503] Done: TAP
# [323/503] Done: MDLZ
# [324/503] Done: MPWR
# [325/503] Done: MNST
# [326/503] Done: MCO
# [327/503] Done: MS
# [328/503] Done: MOS
# [329/503] Done: MSI
# [330/503] Done: MSCI
# [331/503] Done: NDAQ
# [332/503] Done: NTAP
# [333/503] Done: NFLX
# [334/503] Done: NEM
# [335/503] Done: NWSA
# [336/503] Done: NWS
# [337/503] Done: NEE
# [338/503] Done: NKE
# [339/503] Done: NI
# [340/503] Done: NDSN
# [341/503] Done: NSC
# [342/503] Done: NTRS
# [343/503] Done: NOC
# [344/503] Done: NCLH
# [345/503] Done: NRG
# [346/503] Done: NUE
# [347/503] Done: NVDA
# [348/503] Done: NVR
# [349/503] Done: NXPI
# [350/503] Done: ORLY
# [351/503] Done: OXY
# [352/503] Done: ODFL
# [353/503] Done: OMC
# [354/503] Done: ON
# [355/503] Done: OKE
# [356/503] Done: ORCL
# [357/503] Done: OTIS
# [358/503] Done: PCAR
# [359/503] Done: PKG
# [360/503] Done: PLTR
# [361/503] Done: PANW
# [362/503] Done: PSKY
# [363/503] Done: PH
# [364/503] Done: PAYX
# [365/503] Done: PAYC
# [366/503] Done: PYPL
# [367/503] Done: PNR
# [368/503] Done: PEP
# [369/503] Done: PFE
# [370/503] Done: PCG
# [371/503] Done: PM
# [372/503] Done: PSX
# [373/503] Done: PNW
# [374/503] Done: PNC
# [375/503] Done: POOL
# [376/503] Done: PPG
# [377/503] Done: PPL
# [378/503] Done: PFG
# [379/503] Done: PG
# [380/503] Done: PGR
# [381/503] Done: PLD
# [382/503] Done: PRU
# [383/503] Done: PEG
# [384/503] Done: PTC
# [385/503] Done: PSA
# [386/503] Done: PHM
# [387/503] Done: PWR
# [388/503] Done: QCOM
# [389/503] Done: DGX
# [390/503] Done: RL
# [391/503] Done: RJF
# [392/503] Done: RTX
# [393/503] Done: O
# [394/503] Done: REG
# [395/503] Done: REGN
# [396/503] Done: RF
# [397/503] Done: RSG
# [398/503] Done: RMD
# [399/503] Done: RVTY
# [400/503] Done: HOOD
# [401/503] Done: ROK
# [402/503] Done: ROL
# [403/503] Done: ROP
# [404/503] Done: ROST
# [405/503] Done: RCL
# [406/503] Done: SPGI
# [407/503] Done: CRM
# [408/503] Done: SBAC
# [409/503] Done: SLB
# [410/503] Done: STX
# [411/503] Done: SRE
# [412/503] Done: NOW
# [413/503] Done: SHW
# [414/503] Done: SPG
# [415/503] Done: SWKS
# [416/503] Done: SJM
# [417/503] Done: SW
# [418/503] Done: SNA
# [419/503] Done: SOLV
# [420/503] Done: SO
# [421/503] Done: LUV
# [422/503] Done: SWK
# [423/503] Done: SBUX
# [424/503] Done: STT
# [425/503] Done: STLD
# [426/503] Done: STE
# [427/503] Done: SYK
# [428/503] Done: SMCI
# [429/503] Done: SYF
# [430/503] Done: SNPS
# [431/503] Done: SYY
# [432/503] Done: TMUS
# [433/503] Done: TROW
# [434/503] Done: TTWO
# [435/503] Done: TPR
# [436/503] Done: TRGP
# [437/503] Done: TGT
# [438/503] Done: TEL
# [439/503] Done: TDY
# [440/503] Done: TER
# [441/503] Done: TSLA
# [442/503] Done: TXN
# [443/503] Done: TPL
# [444/503] Done: TXT
# [445/503] Done: TMO
# [446/503] Done: TJX
# [447/503] Done: TKO
# [448/503] Done: TTD
# [449/503] Done: TSCO
# [450/503] Done: TT
# [451/503] Done: TDG
# [452/503] Done: TRV
# [453/503] Done: TRMB
# [454/503] Done: TFC
# [455/503] Done: TYL
# [456/503] Done: TSN
# [457/503] Done: USB
# [458/503] Done: UBER
# [459/503] Done: UDR
# [460/503] Done: ULTA
# [461/503] Done: UNP
# [462/503] Done: UAL
# [463/503] Done: UPS
# [464/503] Done: URI
# [465/503] Done: UNH
# [466/503] Done: UHS
# [467/503] Done: VLO
# [468/503] Done: VTR
# [469/503] Done: VLTO
# [470/503] Done: VRSN
# [471/503] Done: VRSK
# [472/503] Done: VZ
# [473/503] Done: VRTX
# [474/503] Done: VTRS
# [475/503] Done: VICI
# [476/503] Done: V
# [477/503] Done: VST
# [478/503] Done: VMC
# [479/503] Done: WRB
# [480/503] Done: GWW
# [481/503] Done: WAB
# [482/503] Done: WMT
# [483/503] Done: DIS
# [484/503] Done: WBD
# [485/503] Done: WM
# [486/503] Done: WAT
# [487/503] Done: WEC
# [488/503] Done: WFC
# [489/503] Done: WELL
# [490/503] Done: WST
# [491/503] Done: WDC
# [492/503] Done: WY
# [493/503] Done: WSM
# [494/503] Done: WMB
# [495/503] Done: WTW
# [496/503] Done: WDAY
# [497/503] Done: WYNN
# [498/503] Done: XEL
# [499/503] Done: XYL
# [500/503] Done: YUM
# [501/503] Done: ZBRA
# [502/503] Done: ZBH
# [503/503] Done: ZTS
#                              Full Name  ROE Power
# Ticker
# MMM                         3M Company   0.495245
# AOS            A. O. Smith Corporation   8.141514
# ABT                Abbott Laboratories  13.258325
# ABBV                       AbbVie Inc.   2.195426
# ACN                      Accenture plc  46.315703
# ...                                ...        ...
# XYL                         Xylem Inc.  34.880909
# YUM                  Yum! Brands, Inc.  25.861832
# ZBRA    Zebra Technologies Corporation  14.603728
# ZBH       Zimmer Biomet Holdings, Inc.  31.104708
# ZTS                        Zoetis Inc.  38.174509
#
# [501 rows x 2 columns]
#
# Saved to sp500_roe_power.csv ✅

# %%
print(ROE.sort_values(by="ROE Power", ascending=False))
# Out:
#                                   Full Name  \
# Ticker
# LNT              Alliant Energy Corporation
# ELV                   Elevance Health, Inc.
# AEE                      Ameren Corporation
# CPRT                           Copart, Inc.
# XEL                        Xcel Energy Inc.
# ...                                     ...
# MSI                Motorola Solutions, Inc.
# MTCH                      Match Group, Inc.
# NCLH    Norwegian Cruise Line Holdings Ltd.
# MTD       Mettler-Toledo International Inc.
# MCK                    McKesson Corporation
#
#                                               ROE History  \
# Ticker
# LNT     [0.09851513420902341, 0.10373321528700015, 0.1...
# ELV     [0.1447416192666102, 0.1523177123085534, 0.162...
# AEE     [0.09757305596830114, 0.10150674068199841, 0.1...
# CPRT    [0.181156034992506, 0.20672290661785336, 0.235...
# XEL     [0.09917016699108698, 0.10053360581289737, 0.1...
# ...                                                   ...
# MSI     [0.9260129183793306, 2.360497237569061, 11.75,...
# MTCH    [-8.659828146844909, -33.330212809494576, -1.0...
# NCLH    [0.6385801146173214, 0.5524406014487695, -33.0...
# MTD     [-6.8022696824020805, -5.260694420360416, 35.1...
# MCK     [-1.5230847285641806, -1.9186860527732903, -0....
#
#                                               ROE Changes   ROE Power
# Ticker
# LNT     [0.005218081077976736, 0.005572074706626365, 0...  963.818139
# ELV     [0.007576093041943205, 0.010306794492759952, 0...  850.258039
# AEE     [0.003933684713697275, 0.0007011009624629527, ...  568.871257
# CPRT    [0.025566871625347376, 0.028950354293868552, 0...  557.801613
# XEL     [0.0013634388218103921, 0.0035743402140891306,...  452.098677
# ...                                                   ...         ...
# MSI       [1.4344843191897303, 9.38950276243094, -42.875]    0.043491
# MTCH    [-24.670384662649667, 32.31831423360017, -0.34...    0.042829
# NCLH    [-0.08613951316855195, -33.645834778527394, 31...    0.037743
# MTD     [1.5415752620416647, 40.4521597533173, -30.705...    0.034373
# MCK     [-0.39560132420910965, 1.4261684471394875, 216...    0.009817
#
# [501 rows x 4 columns]

# %% [markdown]
# ### Return on Invested Capital

# %%
# sp500_roic_power_fixed.py

import yfinance as yf
import pandas as pd
import numpy as np
import time
import requests
from io import StringIO

# 1) Get S&P500 list from Wikipedia (avoid HTTP 403)
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}

response = requests.get(url, headers=headers)
if response.status_code != 200:
    raise Exception(f"Failed to fetch S&P 500 list. HTTP {response.status_code}")

sp500 = pd.read_html(StringIO(response.text))[0]
sp500.columns = [c.strip() for c in sp500.columns]
sp500 = sp500.rename(columns={"Symbol": "Ticker", "Security": "Full Name"})

# 2) Helper to find correct row label
def find_label(labels, candidates):
    for cand in candidates:
        mask = labels.str.contains(cand, case=False, na=False)
        if mask.any():
            return labels[mask].index[0]
    return None

# 3) Compute ROIC Power
def collect_roic_power(ticker, n_years=5):
    try:
        t = yf.Ticker(ticker)
        fin = t.financials
        bs = t.balance_sheet

        if fin is None or fin.empty or bs is None or bs.empty:
            return None

        # Find key rows
        op_label = find_label(fin.index.to_series(), ["operating income", "ebit", "oper income"])
        ta_label = find_label(bs.index.to_series(), ["total assets"])
        cl_label = find_label(bs.index.to_series(), ["current liabilities"])

        if op_label is None or ta_label is None or cl_label is None:
            return None

        op = fin.loc[op_label]
        ta = bs.loc[ta_label]
        cl = bs.loc[cl_label]

        # Compute ROIC history: EBIT / (Total Assets - Current Liabilities)
        roic = []
        for date in op.index:
            o, a, c = op.get(date), ta.get(date), cl.get(date)
            dc = a - c if pd.notna(a) and pd.notna(c) else None
            if pd.notna(o) and dc and dc != 0:
                roic.append(o / dc)
            if len(roic) >= n_years:
                break

        if len(roic) < 2:
            return None

        # Compute year-to-year changes and ROIC Power
        changes = np.diff(roic)
        sd = np.std(changes, ddof=0)
        power = float("inf") if sd == 0 else 1.0 / sd

        return {
            "Ticker": ticker,
            "Full Name": t.info.get("longName", np.nan),
            "ROIC History": roic,
            "ROIC Changes": changes.tolist(),
            "ROIC Power": power
        }

    except Exception as e:
        print(f"Error processing {ticker}: {e}")
        return None

# 4) Loop & collect
results = []
for i, row in sp500.iterrows():
    ticker = row["Ticker"]
    rec = collect_roic_power(ticker)
    if rec:
        results.append(rec)
    print(f"[{i+1}/{len(sp500)}] Done: {ticker}")
    time.sleep(1)  # polite delay to avoid API throttling

# 5) Save and display
df = pd.DataFrame(results).set_index("Ticker")
print(df[["Full Name", "ROIC Power"]])
df.to_csv("sp500_roic_power.csv", index=True)
print("\nSaved to sp500_roic_power.csv ✅")
# Out:
# [1/503] Done: MMM
# [2/503] Done: AOS
# [3/503] Done: ABT
# [4/503] Done: ABBV
# [5/503] Done: ACN
# [6/503] Done: ADBE
# [7/503] Done: AMD
# [8/503] Done: AES
# [9/503] Done: AFL
# [10/503] Done: A
# [11/503] Done: APD
# [12/503] Done: ABNB
# [13/503] Done: AKAM
# [14/503] Done: ALB
# [15/503] Done: ARE
# [16/503] Done: ALGN
# [17/503] Done: ALLE
# [18/503] Done: LNT
# [19/503] Done: ALL
# [20/503] Done: GOOGL
# [21/503] Done: GOOG
# [22/503] Done: MO
# [23/503] Done: AMZN
# [24/503] Done: AMCR
# [25/503] Done: AEE
# [26/503] Done: AEP
# [27/503] Done: AXP
# [28/503] Done: AIG
# [29/503] Done: AMT
# [30/503] Done: AWK
# [31/503] Done: AMP
# [32/503] Done: AME
# [33/503] Done: AMGN
# [34/503] Done: APH
# [35/503] Done: ADI
# [36/503] Done: AON
# [37/503] Done: APA
# [38/503] Done: APO
# [39/503] Done: AAPL
# [40/503] Done: AMAT
# [41/503] Done: APP
# [42/503] Done: APTV
# [43/503] Done: ACGL
# [44/503] Done: ADM
# [45/503] Done: ANET
# [46/503] Done: AJG
# [47/503] Done: AIZ
# [48/503] Done: T
# [49/503] Done: ATO
# [50/503] Done: ADSK
# [51/503] Done: ADP
# [52/503] Done: AZO
# [53/503] Done: AVB
# [54/503] Done: AVY
# [55/503] Done: AXON
# [56/503] Done: BKR
# [57/503] Done: BALL
# [58/503] Done: BAC
# [59/503] Done: BAX
# [60/503] Done: BDX
# [61/503] Done: BRK.B
# [62/503] Done: BBY
# [63/503] Done: TECH
# [64/503] Done: BIIB
# [65/503] Done: BLK
# [66/503] Done: BX
# [67/503] Done: XYZ
# [68/503] Done: BK
# [69/503] Done: BA
# [70/503] Done: BKNG
# [71/503] Done: BSX
# [72/503] Done: BMY
# [73/503] Done: AVGO
# [74/503] Done: BR
# [75/503] Done: BRO
# [76/503] Done: BF.B
# [77/503] Done: BLDR
# [78/503] Done: BG
# [79/503] Done: BXP
# [80/503] Done: CHRW
# [81/503] Done: CDNS
# [82/503] Done: CPT
# [83/503] Done: CPB
# [84/503] Done: COF
# [85/503] Done: CAH
# [86/503] Done: KMX
# [87/503] Done: CCL
# [88/503] Done: CARR
# [89/503] Done: CAT
# [90/503] Done: CBOE
# [91/503] Done: CBRE
# [92/503] Done: CDW
# [93/503] Done: COR
# [94/503] Done: CNC
# [95/503] Done: CNP
# [96/503] Done: CF
# [97/503] Done: CRL
# [98/503] Done: SCHW
# [99/503] Done: CHTR
# [100/503] Done: CVX
# [101/503] Done: CMG
# [102/503] Done: CB
# [103/503] Done: CHD
# [104/503] Done: CI
# [105/503] Done: CINF
# [106/503] Done: CTAS
# [107/503] Done: CSCO
# [108/503] Done: C
# [109/503] Done: CFG
# [110/503] Done: CLX
# [111/503] Done: CME
# [112/503] Done: CMS
# [113/503] Done: KO
# [114/503] Done: CTSH
# [115/503] Done: COIN
# [116/503] Done: CL
# [117/503] Done: CMCSA
# [118/503] Done: CAG
# [119/503] Done: COP
# [120/503] Done: ED
# [121/503] Done: STZ
# [122/503] Done: CEG
# [123/503] Done: COO
# [124/503] Done: CPRT
# [125/503] Done: GLW
# [126/503] Done: CPAY
# [127/503] Done: CTVA
# [128/503] Done: CSGP
# [129/503] Done: COST
# [130/503] Done: CTRA
# [131/503] Done: CRWD
# [132/503] Done: CCI
# [133/503] Done: CSX
# [134/503] Done: CMI
# [135/503] Done: CVS
# [136/503] Done: DHR
# [137/503] Done: DRI
# [138/503] Done: DDOG
# [139/503] Done: DVA
# [140/503] Done: DAY
# [141/503] Done: DECK
# [142/503] Done: DE
# [143/503] Done: DELL
# [144/503] Done: DAL
# [145/503] Done: DVN
# [146/503] Done: DXCM
# [147/503] Done: FANG
# [148/503] Done: DLR
# [149/503] Done: DG
# [150/503] Done: DLTR
# [151/503] Done: D
# [152/503] Done: DPZ
# [153/503] Done: DASH
# [154/503] Done: DOV
# [155/503] Done: DOW
# [156/503] Done: DHI
# [157/503] Done: DTE
# [158/503] Done: DUK
# [159/503] Done: DD
# [160/503] Done: EMN
# [161/503] Done: ETN
# [162/503] Done: EBAY
# [163/503] Done: ECL
# [164/503] Done: EIX
# [165/503] Done: EW
# [166/503] Done: EA
# [167/503] Done: ELV
# [168/503] Done: EME
# [169/503] Done: EMR
# [170/503] Done: ETR
# [171/503] Done: EOG
# [172/503] Done: EPAM
# [173/503] Done: EQT
# [174/503] Done: EFX
# [175/503] Done: EQIX
# [176/503] Done: EQR
# [177/503] Done: ERIE
# [178/503] Done: ESS
# [179/503] Done: EL
# [180/503] Done: EG
# [181/503] Done: EVRG
# [182/503] Done: ES
# [183/503] Done: EXC
# [184/503] Done: EXE
# [185/503] Done: EXPE
# [186/503] Done: EXPD
# [187/503] Done: EXR
# [188/503] Done: XOM
# [189/503] Done: FFIV
# [190/503] Done: FDS
# [191/503] Done: FICO
# [192/503] Done: FAST
# [193/503] Done: FRT
# [194/503] Done: FDX
# [195/503] Done: FIS
# [196/503] Done: FITB
# [197/503] Done: FSLR
# [198/503] Done: FE
# [199/503] Done: FI
# [200/503] Done: F
# [201/503] Done: FTNT
# [202/503] Done: FTV
# [203/503] Done: FOXA
# [204/503] Done: FOX
# [205/503] Done: BEN
# [206/503] Done: FCX
# [207/503] Done: GRMN
# [208/503] Done: IT
# [209/503] Done: GE
# [210/503] Done: GEHC
# [211/503] Done: GEV
# [212/503] Done: GEN
# [213/503] Done: GNRC
# [214/503] Done: GD
# [215/503] Done: GIS
# [216/503] Done: GM
# [217/503] Done: GPC
# [218/503] Done: GILD
# [219/503] Done: GPN
# [220/503] Done: GL
# [221/503] Done: GDDY
# [222/503] Done: GS
# [223/503] Done: HAL
# [224/503] Done: HIG
# [225/503] Done: HAS
# [226/503] Done: HCA
# [227/503] Done: DOC
# [228/503] Done: HSIC
# [229/503] Done: HSY
# [230/503] Done: HPE
# [231/503] Done: HLT
# [232/503] Done: HOLX
# [233/503] Done: HD
# [234/503] Done: HON
# [235/503] Done: HRL
# [236/503] Done: HST
# [237/503] Done: HWM
# [238/503] Done: HPQ
# [239/503] Done: HUBB
# [240/503] Done: HUM
# [241/503] Done: HBAN
# [242/503] Done: HII
# [243/503] Done: IBM
# [244/503] Done: IEX
# [245/503] Done: IDXX
# [246/503] Done: ITW
# [247/503] Done: INCY
# [248/503] Done: IR
# [249/503] Done: PODD
# [250/503] Done: INTC
# [251/503] Done: IBKR
# [252/503] Done: ICE
# [253/503] Done: IFF
# [254/503] Done: IP
# [255/503] Done: IPG
# [256/503] Done: INTU
# [257/503] Done: ISRG
# [258/503] Done: IVZ
# [259/503] Done: INVH
# [260/503] Done: IQV
# [261/503] Done: IRM
# [262/503] Done: JBHT
# [263/503] Done: JBL
# [264/503] Done: JKHY
# [265/503] Done: J
# [266/503] Done: JNJ
# [267/503] Done: JCI
# [268/503] Done: JPM
# [269/503] Done: K
# [270/503] Done: KVUE
# [271/503] Done: KDP
# [272/503] Done: KEY
# [273/503] Done: KEYS
# [274/503] Done: KMB
# [275/503] Done: KIM
# [276/503] Done: KMI
# [277/503] Done: KKR
# [278/503] Done: KLAC
# [279/503] Done: KHC
# [280/503] Done: KR
# [281/503] Done: LHX
# [282/503] Done: LH
# [283/503] Done: LRCX
# [284/503] Done: LW
# [285/503] Done: LVS
# [286/503] Done: LDOS
# [287/503] Done: LEN
# [288/503] Done: LII
# [289/503] Done: LLY
# [290/503] Done: LIN
# [291/503] Done: LYV
# [292/503] Done: LKQ
# [293/503] Done: LMT
# [294/503] Done: L
# [295/503] Done: LOW
# [296/503] Done: LULU
# [297/503] Done: LYB
# [298/503] Done: MTB
# [299/503] Done: MPC
# [300/503] Done: MAR
# [301/503] Done: MMC
# [302/503] Done: MLM
# [303/503] Done: MAS
# [304/503] Done: MA
# [305/503] Done: MTCH
# [306/503] Done: MKC
# [307/503] Done: MCD
# [308/503] Done: MCK
# [309/503] Done: MDT
# [310/503] Done: MRK
# [311/503] Done: META
# [312/503] Done: MET
# [313/503] Done: MTD
# [314/503] Done: MGM
# [315/503] Done: MCHP
# [316/503] Done: MU
# [317/503] Done: MSFT
# [318/503] Done: MAA
# [319/503] Done: MRNA
# [320/503] Done: MHK
# [321/503] Done: MOH
# [322/503] Done: TAP
# [323/503] Done: MDLZ
# [324/503] Done: MPWR
# [325/503] Done: MNST
# [326/503] Done: MCO
# [327/503] Done: MS
# [328/503] Done: MOS
# [329/503] Done: MSI
# [330/503] Done: MSCI
# [331/503] Done: NDAQ
# [332/503] Done: NTAP
# [333/503] Done: NFLX
# [334/503] Done: NEM
# [335/503] Done: NWSA
# [336/503] Done: NWS
# [337/503] Done: NEE
# [338/503] Done: NKE
# [339/503] Done: NI
# [340/503] Done: NDSN
# [341/503] Done: NSC
# [342/503] Done: NTRS
# [343/503] Done: NOC
# [344/503] Done: NCLH
# [345/503] Done: NRG
# [346/503] Done: NUE
# [347/503] Done: NVDA
# [348/503] Done: NVR
# [349/503] Done: NXPI
# [350/503] Done: ORLY
# [351/503] Done: OXY
# [352/503] Done: ODFL
# [353/503] Done: OMC
# [354/503] Done: ON
# [355/503] Done: OKE
# [356/503] Done: ORCL
# [357/503] Done: OTIS
# [358/503] Done: PCAR
# [359/503] Done: PKG
# [360/503] Done: PLTR
# [361/503] Done: PANW
# [362/503] Done: PSKY
# [363/503] Done: PH
# [364/503] Done: PAYX
# [365/503] Done: PAYC
# [366/503] Done: PYPL
# [367/503] Done: PNR
# [368/503] Done: PEP
# [369/503] Done: PFE
# [370/503] Done: PCG
# [371/503] Done: PM
# [372/503] Done: PSX
# [373/503] Done: PNW
# [374/503] Done: PNC
# [375/503] Done: POOL
# [376/503] Done: PPG
# [377/503] Done: PPL
# [378/503] Done: PFG
# [379/503] Done: PG
# [380/503] Done: PGR
# [381/503] Done: PLD
# [382/503] Done: PRU
# [383/503] Done: PEG
# [384/503] Done: PTC
# [385/503] Done: PSA
# [386/503] Done: PHM
# [387/503] Done: PWR
# [388/503] Done: QCOM
# [389/503] Done: DGX
# [390/503] Done: RL
# [391/503] Done: RJF
# [392/503] Done: RTX
# [393/503] Done: O
# [394/503] Done: REG
# [395/503] Done: REGN
# [396/503] Done: RF
# [397/503] Done: RSG
# [398/503] Done: RMD
# [399/503] Done: RVTY
# [400/503] Done: HOOD
# [401/503] Done: ROK
# [402/503] Done: ROL
# [403/503] Done: ROP
# [404/503] Done: ROST
# [405/503] Done: RCL
# [406/503] Done: SPGI
# [407/503] Done: CRM
# [408/503] Done: SBAC
# [409/503] Done: SLB
# [410/503] Done: STX
# [411/503] Done: SRE
# [412/503] Done: NOW
# [413/503] Done: SHW
# [414/503] Done: SPG
# [415/503] Done: SWKS
# [416/503] Done: SJM
# [417/503] Done: SW
# [418/503] Done: SNA
# [419/503] Done: SOLV
# [420/503] Done: SO
# [421/503] Done: LUV
# [422/503] Done: SWK
# [423/503] Done: SBUX
# [424/503] Done: STT
# [425/503] Done: STLD
# [426/503] Done: STE
# [427/503] Done: SYK
# [428/503] Done: SMCI
# [429/503] Done: SYF
# [430/503] Done: SNPS
# [431/503] Done: SYY
# [432/503] Done: TMUS
# [433/503] Done: TROW
# [434/503] Done: TTWO
# [435/503] Done: TPR
# [436/503] Done: TRGP
# [437/503] Done: TGT
# [438/503] Done: TEL
# [439/503] Done: TDY
# [440/503] Done: TER
# [441/503] Done: TSLA
# [442/503] Done: TXN
# [443/503] Done: TPL
# [444/503] Done: TXT
# [445/503] Done: TMO
# [446/503] Done: TJX
# [447/503] Done: TKO
# [448/503] Done: TTD
# [449/503] Done: TSCO
# [450/503] Done: TT
# [451/503] Done: TDG
# [452/503] Done: TRV
# [453/503] Done: TRMB
# [454/503] Done: TFC
# [455/503] Done: TYL
# [456/503] Done: TSN
# [457/503] Done: USB
# [458/503] Done: UBER
# [459/503] Done: UDR
# [460/503] Done: ULTA
# [461/503] Done: UNP
# [462/503] Done: UAL
# [463/503] Done: UPS
# [464/503] Done: URI
# [465/503] Done: UNH
# [466/503] Done: UHS
# [467/503] Done: VLO
# [468/503] Done: VTR
# [469/503] Done: VLTO
# [470/503] Done: VRSN
# [471/503] Done: VRSK
# [472/503] Done: VZ
# [473/503] Done: VRTX
# [474/503] Done: VTRS
# [475/503] Done: VICI
# [476/503] Done: V
# [477/503] Done: VST
# [478/503] Done: VMC
# [479/503] Done: WRB
# [480/503] Done: GWW
# [481/503] Done: WAB
# [482/503] Done: WMT
# [483/503] Done: DIS
# [484/503] Done: WBD
# [485/503] Done: WM
# [486/503] Done: WAT
# [487/503] Done: WEC
# [488/503] Done: WFC
# [489/503] Done: WELL
# [490/503] Done: WST
# [491/503] Done: WDC
# [492/503] Done: WY
# [493/503] Done: WSM
# [494/503] Done: WMB
# [495/503] Done: WTW
# [496/503] Done: WDAY
# [497/503] Done: WYNN
# [498/503] Done: XEL
# [499/503] Done: XYL
# [500/503] Done: YUM
# [501/503] Done: ZBRA
# [502/503] Done: ZBH
# [503/503] Done: ZTS
#                              Full Name  ROIC Power
# Ticker
# MMM                         3M Company    1.485359
# AOS            A. O. Smith Corporation    7.495625
# ABT                Abbott Laboratories   87.776223
# ABBV                       AbbVie Inc.   15.765511
# ACN                      Accenture plc   44.430643
# ...                                ...         ...
# XYL                         Xylem Inc.   25.645640
# YUM                  Yum! Brands, Inc.   46.110014
# ZBRA    Zebra Technologies Corporation   17.330478
# ZBH       Zimmer Biomet Holdings, Inc.   58.102030
# ZTS                        Zoetis Inc.  288.321876
#
# [452 rows x 2 columns]
#
# Saved to sp500_roic_power.csv ✅
