# %% [markdown]
# ### Pricing power using Bloomberg inverse of the standard deviation of gross margins

# %%
# Bloomberg-style Pricing Power (GPM stability) — self-contained + 403-safe S&P500 fetch

# ---------- 0) AUTO-INSTALL DEPENDENCIES ----------
import sys, subprocess, importlib

REQUIRED_PACKAGES = [
    "yfinance",
    "pandas",
    "numpy",
    "lxml",
    "beautifulsoup4",
    "html5lib",
    "requests",
    "openpyxl",  # for to_excel
]

def ensure_packages(pkgs):
    for p in pkgs:
        try:
            importlib.import_module(p if p != "beautifulsoup4" else "bs4")
        except ImportError:
            print(f"Installing missing package: {p} …")
            subprocess.check_call([sys.executable, "-m", "pip", "install", p])

ensure_packages(REQUIRED_PACKAGES)

# ---------- 1) IMPORTS ----------
import re
import time
import math
import io
import numpy as np
import pandas as pd
import requests
import yfinance as yf
from typing import Optional, List, Dict

# ---------- 2) CONFIG ----------
MAX_YEARS = 5                   # number of most recent annual GPMs to use
SLEEP_SEC = 0.5                 # throttle between ticker calls
RETRY_N = 2                     # simple retry for transient errors
EXCLUDE_FINANCIALS = True       # Bloomberg often excludes Financials/REITs
EXCLUDE_YOUNG_YEARS = 0         # set >0 to exclude firms younger than N years from Wiki "Founded"
OUTPUT_CSV = "sp500_pricing_power.csv"

UA = (
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
    "AppleWebKit/537.36 (KHTML, like Gecko) "
    "Chrome/127.0.0.1 Safari/537.36"
)

# ---------- 3) S&P500 FETCHERS (robust to 403) ----------
def fetch_sp500_from_wikipedia() -> pd.DataFrame:
    """
    Primary: requests.get with headers -> pd.read_html on the HTML
    Secondary: pd.read_html with storage_options (may or may not work on some pandas versions)
    """
    wiki = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

    # Primary path: requests + read_html
    try:
        with requests.Session() as s:
            s.headers.update({"User-Agent": UA})
            r = s.get(wiki, timeout=20)
            r.raise_for_status()
            tables = pd.read_html(r.text)
            if tables:
                return tables[0]
    except Exception as e:
        last_err = f"requests+read_html failed: {e}"

    # Secondary path: direct read_html with storage_options (not always honored)
    try:
        tables = pd.read_html(wiki, storage_options={"User-Agent": UA})
        if tables:
            return tables[0]
    except Exception as e:
        last_err = f"pd.read_html(storage_options) failed: {e}"

    raise RuntimeError(f"Wikipedia fetch failed. Last error: {last_err}")

def fetch_sp500_from_fallback() -> pd.DataFrame:
    """
    Fallback source (community dataset). Schema: Symbol,Security, etc.
    Note: may lag Wikipedia updates, but avoids 403s.
    """
    url_csv = "https://raw.githubusercontent.com/datasets/s-and-p-500-companies/master/data/constituents.csv"
    with requests.Session() as s:
        s.headers.update({"User-Agent": UA})
        r = s.get(url_csv, timeout=20)
        r.raise_for_status()
        df = pd.read_csv(io.StringIO(r.text))
    return df

def get_sp500_table() -> pd.DataFrame:
    """
    Returns columns: Ticker, Full Name, Sector, Sub-Industry, Date Added, Founded (Wiki) (if available)
    """
    try:
        df = fetch_sp500_from_wikipedia()
        source = "wikipedia"
    except Exception:
        df = fetch_sp500_from_fallback()
        source = "fallback"

    # Normalize column names
    df.columns = [c.strip() for c in df.columns]
    mapper = {
        "Symbol": "Ticker",
        "Security": "Full Name",
        "GICS Sector": "Sector",
        "GICS Sub-Industry": "Sub-Industry",
        "Date added": "Date Added",
        "Founded": "Founded (Wiki)",
    }
    for old, new in mapper.items():
        if old in df.columns:
            df = df.rename(columns={old: new})

    # Ensure essential columns
    if "Ticker" not in df.columns or "Full Name" not in df.columns:
        raise RuntimeError(f"S&P 500 table from {source} missing essential columns.")

    # Add missing optional columns
    for col in ["Sector", "Sub-Industry", "Date Added", "Founded (Wiki)"]:
        if col not in df.columns:
            df[col] = np.nan

    keep_cols = ["Ticker", "Full Name", "Sector", "Sub-Industry", "Date Added", "Founded (Wiki)"]
    return df[keep_cols].copy()

# ---------- 4) TICKER NORMALIZATION ----------
def yf_ticker(symbol: str) -> str:
    # yfinance expects dashes for class shares (e.g., BRK-B)
    return symbol.replace(".", "-").strip()

# ---------- 5) HELPERS ----------
def find_label(idx: pd.Index, candidates: List[str]) -> Optional[str]:
    """Return the first index entry that contains any candidate (case-insensitive)."""
    s = idx.to_series().astype(str)
    for cand in candidates:
        mask = s.str.contains(cand, case=False, na=False)
        if mask.any():
            # Return the exact index label (string) to use with .loc
            return s[mask].index[0]
    return None

def parse_year(x) -> Optional[int]:
    """Extract a 4-digit year from strings like '1888', '2009 (1887)', 'c. 1901', etc."""
    if pd.isna(x): 
        return None
    m = re.search(r"(18|19|20)\d{2}", str(x))
    return int(m.group(0)) if m else None

def get_income_stmt(tkr: yf.Ticker) -> Optional[pd.DataFrame]:
    """
    Retrieve annual income statement across yfinance versions:
    - prefer .income_stmt (new API)
    - fallback .financials (older API)
    - final attempt: .get_income_stmt()
    """
    for attr in ("income_stmt", "financials"):
        try:
            df = getattr(tkr, attr, None)
            if isinstance(df, pd.DataFrame) and not df.empty:
                return df
        except Exception:
            pass
    try:
        df = tkr.get_income_stmt()
        if isinstance(df, pd.DataFrame) and not df.empty:
            return df
    except Exception:
        pass
    return None

def safe_get_info_item(tkr: yf.Ticker, key: str):
    try:
        info = tkr.info
        return info.get(key, np.nan) if isinstance(info, dict) else np.nan
    except Exception:
        return np.nan

def collect_pricing_power(row: pd.Series) -> Optional[Dict]:
    """
    Compute 'pricing power' = 1 / std of last up-to-5 annual gross margins.
    Returns dict with metadata/metrics or None if insufficient data.
    """
    ticker = row["YF Ticker"]
    orig_ticker = row["Ticker"]
    last_err = None

    for attempt in range(1, RETRY_N + 2):
        try:
            t = yf.Ticker(ticker)
            fin = get_income_stmt(t)
            if fin is None or fin.empty:
                last_err = "no financials"
                break

            idx = fin.index
            rev_label  = find_label(idx, ["total revenue", "revenue"])
            cogs_label = find_label(idx, ["cost of revenue", "cost of goods sold", "cost revenue"])
            if not rev_label or not cogs_label:
                last_err = f"missing rows → rev={rev_label}, cogs={cogs_label}"
                break

            revenue = fin.loc[rev_label].dropna()
            cogs    = fin.loc[cogs_label].dropna()

            # Align on common columns (dates)
            common_cols = [c for c in revenue.index if c in cogs.index]
            if not common_cols:
                last_err = "no overlapping revenue/COGS columns"
                break

            # Sort columns newest→oldest when possible
            try:
                common_cols = sorted(common_cols, reverse=True)
            except Exception:
                pass

            margins: List[float] = []
            for col in common_cols:
                rev = revenue[col]
                cost = cogs[col]
                if pd.notna(rev) and pd.notna(cost) and rev not in (0, 0.0):
                    gm = (rev - cost) / rev
                    if isinstance(gm, (int, float)) and math.isfinite(gm) and -5.0 < gm < 5.0:
                        margins.append(float(gm))
                if len(margins) >= MAX_YEARS:
                    break

            if len(margins) < 2:
                last_err = f"only {len(margins)} gross margins"
                break

            std = float(np.std(margins, ddof=0))
            pricing_power = (1.0 / std) if std != 0 else float("inf")

            founding_year_yf = safe_get_info_item(t, "founded")
            mcap = safe_get_info_item(t, "marketCap")

            # success
            return {
                "Ticker": orig_ticker,
                "YF Ticker": ticker,
                "Full Name": row["Full Name"],
                "Sector": row.get("Sector", np.nan),
                "Sub-Industry": row.get("Sub-Industry", np.nan),
                "Date Added": row.get("Date Added", np.nan),
                "Founded (Wiki)": row.get("Founded (Wiki)", np.nan),
                "Founded_Year_Wiki": row.get("Founded_Year_Wiki", np.nan),
                "Founding Year (YF)": founding_year_yf,
                "Market Cap": mcap,
                "Gross Margins (latest→older)": margins,
                "Pricing Power": pricing_power,
            }

        except Exception as e:
            last_err = str(e)

        # naive backoff on retry
        time.sleep(SLEEP_SEC * attempt)

    print(f"  ❌ {orig_ticker}: {last_err}")
    return None

# ---------- 6) PIPELINE ----------
# 6.1 Fetch S&P500 with 403-safe logic
sp500_df = get_sp500_table()

# 6.2 Normalize & optional filters
sp500_df["YF Ticker"] = sp500_df["Ticker"].map(yf_ticker)
sp500_df["Founded_Year_Wiki"] = sp500_df["Founded (Wiki)"].apply(parse_year)

if EXCLUDE_FINANCIALS and "Sector" in sp500_df.columns:
    sp500_df = sp500_df[~sp500_df["Sector"].isin({"Financials", "Real Estate"})].copy()

if EXCLUDE_YOUNG_YEARS and "Founded_Year_Wiki" in sp500_df.columns:
    current_year = pd.Timestamp.today().year
    mask_old_enough = sp500_df["Founded_Year_Wiki"].apply(
        lambda y: (isinstance(y, (int, np.integer)) and (current_year - int(y) >= EXCLUDE_YOUNG_YEARS))
    )
    sp500_df = sp500_df[mask_old_enough | sp500_df["Founded_Year_Wiki"].isna()].copy()

# 6.3 Iterate & compute
results: List[Dict] = []
n = len(sp500_df)
for i, row in sp500_df.reset_index(drop=True).iterrows():
    print(f"Processing {row['Ticker']} → {row['YF Ticker']}  ({i+1}/{n}) …")
    rec = collect_pricing_power(row)
    if rec:
        results.append(rec)
    time.sleep(SLEEP_SEC)

# 6.4 Output
if results:
    GPM_original = pd.DataFrame(results).set_index("Ticker")
    show_cols = [
        "Full Name", "Sector", "Sub-Industry",
        "Founding Year (YF)", "Founded (Wiki)", "Date Added",
        "Market Cap", "Pricing Power", "Gross Margins (latest→older)"
    ]
    GPM_original = GPM_original.reindex(columns=show_cols)
    GPM_original = GPM_original.sort_values("Pricing Power", ascending=False)

    pd.set_option("display.width", 200)
    pd.set_option("display.max_rows", 50)
    print(GPM_original.head(20))

    GPM_original.to_csv(OUTPUT_CSV, index=True)
    print(f"\nSaved to {OUTPUT_CSV}  (rows: {len(GPM_original)})")
    GPM_original.to_excel('sp500_pricing_power_GPM_original.xlsx', index=True)
else:
    print("No results — likely all tickers failed schema/financial checks.")
# Out:
# Installing missing package: openpyxl …
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]1/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# /tmp/ipykernel_7214/159643754.py:66: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(r.text)
# Processing MMM → MMM  (1/397) …
# Processing AOS → AOS  (2/397) …
# Processing ABT → ABT  (3/397) …
# Processing ABBV → ABBV  (4/397) …
# Processing ACN → ACN  (5/397) …
# Processing ADBE → ADBE  (6/397) …
# Processing AMD → AMD  (7/397) …
# Processing AES → AES  (8/397) …
# Processing A → A  (9/397) …
# Processing APD → APD  (10/397) …
# Processing ABNB → ABNB  (11/397) …
# Processing AKAM → AKAM  (12/397) …
# Processing ALB → ALB  (13/397) …
# Processing ALGN → ALGN  (14/397) …
# Processing ALLE → ALLE  (15/397) …
# Processing LNT → LNT  (16/397) …
# Processing GOOGL → GOOGL  (17/397) …
# Processing GOOG → GOOG  (18/397) …
# Processing MO → MO  (19/397) …
# Processing AMZN → AMZN  (20/397) …
# Processing AMCR → AMCR  (21/397) …
# Processing AEE → AEE  (22/397) …
# Processing AEP → AEP  (23/397) …
# Processing AWK → AWK  (24/397) …
# Processing AME → AME  (25/397) …
# Processing AMGN → AMGN  (26/397) …
# Processing APH → APH  (27/397) …
# Processing ADI → ADI  (28/397) …
# Processing APA → APA  (29/397) …
# Processing AAPL → AAPL  (30/397) …
# Processing AMAT → AMAT  (31/397) …
# Processing APP → APP  (32/397) …
# Processing APTV → APTV  (33/397) …
# Processing ADM → ADM  (34/397) …
# Processing ANET → ANET  (35/397) …
# Processing T → T  (36/397) …
# Processing ATO → ATO  (37/397) …
# Processing ADSK → ADSK  (38/397) …
# Processing ADP → ADP  (39/397) …
# Processing AZO → AZO  (40/397) …
# Processing AVY → AVY  (41/397) …
# Processing AXON → AXON  (42/397) …
# Processing BKR → BKR  (43/397) …
# Processing BALL → BALL  (44/397) …
# Processing BAX → BAX  (45/397) …
# Processing BDX → BDX  (46/397) …
# Processing BBY → BBY  (47/397) …
# Processing TECH → TECH  (48/397) …
# Processing BIIB → BIIB  (49/397) …
# Processing BA → BA  (50/397) …
# Processing BKNG → BKNG  (51/397) …
#   ❌ BKNG: missing rows → rev=Total Revenue, cogs=None
# Processing BSX → BSX  (52/397) …
# Processing BMY → BMY  (53/397) …
# Processing AVGO → AVGO  (54/397) …
# Processing BR → BR  (55/397) …
# Processing BF.B → BF-B  (56/397) …
# Processing BLDR → BLDR  (57/397) …
# Processing BG → BG  (58/397) …
# Processing CHRW → CHRW  (59/397) …
# Processing CDNS → CDNS  (60/397) …
# Processing CPB → CPB  (61/397) …
# Processing CAH → CAH  (62/397) …
# Processing KMX → KMX  (63/397) …
# Processing CCL → CCL  (64/397) …
# Processing CARR → CARR  (65/397) …
# Processing CAT → CAT  (66/397) …
# Processing CDW → CDW  (67/397) …
# Processing COR → COR  (68/397) …
# Processing CNC → CNC  (69/397) …
# Processing CNP → CNP  (70/397) …
# Processing CF → CF  (71/397) …
# Processing CRL → CRL  (72/397) …
# Processing CHTR → CHTR  (73/397) …
# Processing CVX → CVX  (74/397) …
# Processing CMG → CMG  (75/397) …
# Processing CHD → CHD  (76/397) …
# Processing CI → CI  (77/397) …
#   ❌ CI: missing rows → rev=Total Revenue, cogs=None
# Processing CTAS → CTAS  (78/397) …
# Processing CSCO → CSCO  (79/397) …
# Processing CLX → CLX  (80/397) …
# Processing CMS → CMS  (81/397) …
# Processing KO → KO  (82/397) …
# Processing CTSH → CTSH  (83/397) …
# Processing CL → CL  (84/397) …
# Processing CMCSA → CMCSA  (85/397) …
# Processing CAG → CAG  (86/397) …
# Processing COP → COP  (87/397) …
# Processing ED → ED  (88/397) …
# Processing STZ → STZ  (89/397) …
# Processing CEG → CEG  (90/397) …
# Processing COO → COO  (91/397) …
# Processing CPRT → CPRT  (92/397) …
# Processing GLW → GLW  (93/397) …
# Processing CTVA → CTVA  (94/397) …
# Processing COST → COST  (95/397) …
# Processing CTRA → CTRA  (96/397) …
# Processing CRWD → CRWD  (97/397) …
# Processing CSX → CSX  (98/397) …
# Processing CMI → CMI  (99/397) …
# Processing CVS → CVS  (100/397) …
# Processing DHR → DHR  (101/397) …
# Processing DRI → DRI  (102/397) …
# Processing DDOG → DDOG  (103/397) …
# Processing DVA → DVA  (104/397) …
# Processing DAY → DAY  (105/397) …
# Processing DECK → DECK  (106/397) …
# Processing DE → DE  (107/397) …
# Processing DELL → DELL  (108/397) …
# Processing DAL → DAL  (109/397) …
# Processing DVN → DVN  (110/397) …
# Processing DXCM → DXCM  (111/397) …
# Processing FANG → FANG  (112/397) …
# Processing DG → DG  (113/397) …
# Processing DLTR → DLTR  (114/397) …
# Processing D → D  (115/397) …
# Processing DPZ → DPZ  (116/397) …
# Processing DASH → DASH  (117/397) …
# Processing DOV → DOV  (118/397) …
# Processing DOW → DOW  (119/397) …
# Processing DHI → DHI  (120/397) …
# Processing DTE → DTE  (121/397) …
# Processing DUK → DUK  (122/397) …
# Processing DD → DD  (123/397) …
# Processing EMN → EMN  (124/397) …
# Processing ETN → ETN  (125/397) …
# Processing EBAY → EBAY  (126/397) …
# Processing ECL → ECL  (127/397) …
# Processing EIX → EIX  (128/397) …
# Processing EW → EW  (129/397) …
# Processing EA → EA  (130/397) …
# Processing ELV → ELV  (131/397) …
#   ❌ ELV: missing rows → rev=Total Revenue, cogs=None
# Processing EME → EME  (132/397) …
# Processing EMR → EMR  (133/397) …
# Processing ETR → ETR  (134/397) …
# Processing EOG → EOG  (135/397) …
# Processing EPAM → EPAM  (136/397) …
# Processing EQT → EQT  (137/397) …
# Processing EFX → EFX  (138/397) …
# Processing EL → EL  (139/397) …
# Processing EVRG → EVRG  (140/397) …
# Processing ES → ES  (141/397) …
# Processing EXC → EXC  (142/397) …
# Processing EXE → EXE  (143/397) …
# Processing EXPE → EXPE  (144/397) …
# Processing EXPD → EXPD  (145/397) …
# Processing XOM → XOM  (146/397) …
# Processing FFIV → FFIV  (147/397) …
# Processing FICO → FICO  (148/397) …
# Processing FAST → FAST  (149/397) …
# Processing FDX → FDX  (150/397) …
# Processing FSLR → FSLR  (151/397) …
# Processing FE → FE  (152/397) …
# Processing F → F  (153/397) …
# Processing FTNT → FTNT  (154/397) …
# Processing FTV → FTV  (155/397) …
# Processing FOXA → FOXA  (156/397) …
#   ❌ FOXA: missing rows → rev=Total Revenue, cogs=None
# Processing FOX → FOX  (157/397) …
#   ❌ FOX: missing rows → rev=Total Revenue, cogs=None
# Processing FCX → FCX  (158/397) …
# Processing GRMN → GRMN  (159/397) …
# Processing IT → IT  (160/397) …
# Processing GE → GE  (161/397) …
# Processing GEHC → GEHC  (162/397) …
# Processing GEV → GEV  (163/397) …
# Processing GEN → GEN  (164/397) …
# Processing GNRC → GNRC  (165/397) …
# Processing GD → GD  (166/397) …
# Processing GIS → GIS  (167/397) …
# Processing GM → GM  (168/397) …
# Processing GPC → GPC  (169/397) …
# Processing GILD → GILD  (170/397) …
# Processing GDDY → GDDY  (171/397) …
# Processing HAL → HAL  (172/397) …
# Processing HAS → HAS  (173/397) …
# Processing HCA → HCA  (174/397) …
# Processing HSIC → HSIC  (175/397) …
# Processing HSY → HSY  (176/397) …
# Processing HPE → HPE  (177/397) …
# Processing HLT → HLT  (178/397) …
# Processing HOLX → HOLX  (179/397) …
# Processing HD → HD  (180/397) …
# Processing HON → HON  (181/397) …
# Processing HRL → HRL  (182/397) …
# Processing HWM → HWM  (183/397) …
# Processing HPQ → HPQ  (184/397) …
# Processing HUBB → HUBB  (185/397) …
# Processing HUM → HUM  (186/397) …
#   ❌ HUM: missing rows → rev=Total Revenue, cogs=None
# Processing HII → HII  (187/397) …
# Processing IBM → IBM  (188/397) …
# Processing IEX → IEX  (189/397) …
# Processing IDXX → IDXX  (190/397) …
# Processing ITW → ITW  (191/397) …
# Processing INCY → INCY  (192/397) …
# Processing IR → IR  (193/397) …
# Processing PODD → PODD  (194/397) …
# Processing INTC → INTC  (195/397) …
# Processing IFF → IFF  (196/397) …
# Processing IP → IP  (197/397) …
# Processing IPG → IPG  (198/397) …
# Processing INTU → INTU  (199/397) …
# Processing ISRG → ISRG  (200/397) …
# Processing IQV → IQV  (201/397) …
# Processing JBHT → JBHT  (202/397) …
# Processing JBL → JBL  (203/397) …
# Processing J → J  (204/397) …
# Processing JNJ → JNJ  (205/397) …
# Processing JCI → JCI  (206/397) …
# Processing K → K  (207/397) …
# Processing KVUE → KVUE  (208/397) …
# Processing KDP → KDP  (209/397) …
# Processing KEYS → KEYS  (210/397) …
# Processing KMB → KMB  (211/397) …
# Processing KMI → KMI  (212/397) …
# Processing KLAC → KLAC  (213/397) …
# Processing KHC → KHC  (214/397) …
# Processing KR → KR  (215/397) …
# Processing LHX → LHX  (216/397) …
# Processing LH → LH  (217/397) …
# Processing LRCX → LRCX  (218/397) …
# Processing LW → LW  (219/397) …
# Processing LVS → LVS  (220/397) …
# Processing LDOS → LDOS  (221/397) …
# Processing LEN → LEN  (222/397) …
# Processing LII → LII  (223/397) …
# Processing LLY → LLY  (224/397) …
# Processing LIN → LIN  (225/397) …
# Processing LYV → LYV  (226/397) …
# Processing LKQ → LKQ  (227/397) …
# Processing LMT → LMT  (228/397) …
# Processing LOW → LOW  (229/397) …
# Processing LULU → LULU  (230/397) …
# Processing LYB → LYB  (231/397) …
# Processing MPC → MPC  (232/397) …
# Processing MAR → MAR  (233/397) …
# Processing MLM → MLM  (234/397) …
# Processing MAS → MAS  (235/397) …
# Processing MTCH → MTCH  (236/397) …
# Processing MKC → MKC  (237/397) …
# Processing MCD → MCD  (238/397) …
# Processing MCK → MCK  (239/397) …
# Processing MDT → MDT  (240/397) …
# Processing MRK → MRK  (241/397) …
# Processing META → META  (242/397) …
# Processing MTD → MTD  (243/397) …
# Processing MGM → MGM  (244/397) …
# Processing MCHP → MCHP  (245/397) …
# Processing MU → MU  (246/397) …
# Processing MSFT → MSFT  (247/397) …
# Processing MRNA → MRNA  (248/397) …
# Processing MHK → MHK  (249/397) …
# Processing MOH → MOH  (250/397) …
# Processing TAP → TAP  (251/397) …
# Processing MDLZ → MDLZ  (252/397) …
# Processing MPWR → MPWR  (253/397) …
# Processing MNST → MNST  (254/397) …
# Processing MOS → MOS  (255/397) …
# Processing MSI → MSI  (256/397) …
# Processing NTAP → NTAP  (257/397) …
# Processing NFLX → NFLX  (258/397) …
# Processing NEM → NEM  (259/397) …
# Processing NWSA → NWSA  (260/397) …
#   ❌ NWSA: missing rows → rev=Total Revenue, cogs=None
# Processing NWS → NWS  (261/397) …
#   ❌ NWS: missing rows → rev=Total Revenue, cogs=None
# Processing NEE → NEE  (262/397) …
# Processing NKE → NKE  (263/397) …
# Processing NI → NI  (264/397) …
# Processing NDSN → NDSN  (265/397) …
# Processing NSC → NSC  (266/397) …
# Processing NOC → NOC  (267/397) …
# Processing NCLH → NCLH  (268/397) …
# Processing NRG → NRG  (269/397) …
# Processing NUE → NUE  (270/397) …
# Processing NVDA → NVDA  (271/397) …
# Processing NVR → NVR  (272/397) …
# Processing NXPI → NXPI  (273/397) …
# Processing ORLY → ORLY  (274/397) …
# Processing OXY → OXY  (275/397) …
# Processing ODFL → ODFL  (276/397) …
# Processing OMC → OMC  (277/397) …
# Processing ON → ON  (278/397) …
# Processing OKE → OKE  (279/397) …
# Processing ORCL → ORCL  (280/397) …
# Processing OTIS → OTIS  (281/397) …
# Processing PCAR → PCAR  (282/397) …
# Processing PKG → PKG  (283/397) …
# Processing PLTR → PLTR  (284/397) …
# Processing PANW → PANW  (285/397) …
# Processing PSKY → PSKY  (286/397) …
# Processing PH → PH  (287/397) …
# Processing PAYX → PAYX  (288/397) …
# Processing PAYC → PAYC  (289/397) …
# Processing PNR → PNR  (290/397) …
# Processing PEP → PEP  (291/397) …
# Processing PFE → PFE  (292/397) …
# Processing PCG → PCG  (293/397) …
# Processing PM → PM  (294/397) …
# Processing PSX → PSX  (295/397) …
# Processing PNW → PNW  (296/397) …
# Processing POOL → POOL  (297/397) …
# Processing PPG → PPG  (298/397) …
# Processing PPL → PPL  (299/397) …
# Processing PG → PG  (300/397) …
# Processing PEG → PEG  (301/397) …
# Processing PTC → PTC  (302/397) …
# Processing PHM → PHM  (303/397) …
# Processing PWR → PWR  (304/397) …
# Processing QCOM → QCOM  (305/397) …
# Processing DGX → DGX  (306/397) …
# Processing RL → RL  (307/397) …
# Processing RTX → RTX  (308/397) …
# Processing REGN → REGN  (309/397) …
# Processing RSG → RSG  (310/397) …
# Processing RMD → RMD  (311/397) …
# Processing RVTY → RVTY  (312/397) …
# Processing ROK → ROK  (313/397) …
# Processing ROL → ROL  (314/397) …
# Processing ROP → ROP  (315/397) …
# Processing ROST → ROST  (316/397) …
# Processing RCL → RCL  (317/397) …
# Processing CRM → CRM  (318/397) …
# Processing SLB → SLB  (319/397) …
# Processing STX → STX  (320/397) …
# Processing SRE → SRE  (321/397) …
# Processing NOW → NOW  (322/397) …
# Processing SHW → SHW  (323/397) …
# Processing SWKS → SWKS  (324/397) …
# Processing SJM → SJM  (325/397) …
# Processing SW → SW  (326/397) …
# Processing SNA → SNA  (327/397) …
# Processing SOLV → SOLV  (328/397) …
# Processing SO → SO  (329/397) …
# Processing LUV → LUV  (330/397) …
# Processing SWK → SWK  (331/397) …
# Processing SBUX → SBUX  (332/397) …
# Processing STLD → STLD  (333/397) …
# Processing STE → STE  (334/397) …
# Processing SYK → SYK  (335/397) …
# Processing SMCI → SMCI  (336/397) …
# Processing SNPS → SNPS  (337/397) …
# Processing SYY → SYY  (338/397) …
# Processing TMUS → TMUS  (339/397) …
# Processing TTWO → TTWO  (340/397) …
# Processing TPR → TPR  (341/397) …
# Processing TRGP → TRGP  (342/397) …
# Processing TGT → TGT  (343/397) …
# Processing TEL → TEL  (344/397) …
# Processing TDY → TDY  (345/397) …
# Processing TER → TER  (346/397) …
# Processing TSLA → TSLA  (347/397) …
# Processing TXN → TXN  (348/397) …
# Processing TPL → TPL  (349/397) …
# Processing TXT → TXT  (350/397) …
# Processing TMO → TMO  (351/397) …
# Processing TJX → TJX  (352/397) …
# Processing TKO → TKO  (353/397) …
# Processing TTD → TTD  (354/397) …
# Processing TSCO → TSCO  (355/397) …
# Processing TT → TT  (356/397) …
# Processing TDG → TDG  (357/397) …
# Processing TRMB → TRMB  (358/397) …
# Processing TYL → TYL  (359/397) …
# Processing TSN → TSN  (360/397) …
# Processing UBER → UBER  (361/397) …
# Processing ULTA → ULTA  (362/397) …
# Processing UNP → UNP  (363/397) …
# Processing UAL → UAL  (364/397) …
# Processing UPS → UPS  (365/397) …
# Processing URI → URI  (366/397) …
# Processing UNH → UNH  (367/397) …
# Processing UHS → UHS  (368/397) …
# Processing VLO → VLO  (369/397) …
# Processing VLTO → VLTO  (370/397) …
# Processing VRSN → VRSN  (371/397) …
# Processing VRSK → VRSK  (372/397) …
# Processing VZ → VZ  (373/397) …
# Processing VRTX → VRTX  (374/397) …
# Processing VTRS → VTRS  (375/397) …
# Processing VST → VST  (376/397) …
# Processing VMC → VMC  (377/397) …
# Processing GWW → GWW  (378/397) …
# Processing WAB → WAB  (379/397) …
# Processing WMT → WMT  (380/397) …
# Processing DIS → DIS  (381/397) …
# Processing WBD → WBD  (382/397) …
# Processing WM → WM  (383/397) …
# Processing WAT → WAT  (384/397) …
# Processing WEC → WEC  (385/397) …
# Processing WST → WST  (386/397) …
# Processing WDC → WDC  (387/397) …
# Processing WSM → WSM  (388/397) …
# Processing WMB → WMB  (389/397) …
# Processing WDAY → WDAY  (390/397) …
# Processing WYNN → WYNN  (391/397) …
# Processing XEL → XEL  (392/397) …
# Processing XYL → XYL  (393/397) …
# Processing YUM → YUM  (394/397) …
# Processing ZBRA → ZBRA  (395/397) …
# Processing ZBH → ZBH  (396/397) …
# Processing ZTS → ZTS  (397/397) …
#                        Full Name                  Sector                                  Sub-Industry  Founding Year (YF)  Founded (Wiki)  Date Added    Market Cap  Pricing Power  \
# Ticker
# HD              Home Depot (The)  Consumer Discretionary                       Home Improvement Retail                 NaN            1978  1988-03-31  390091997184    1485.287286
# LOW                       Lowe's  Consumer Discretionary                       Home Improvement Retail                 NaN  1904/1946/1959  1984-02-29  137233850368    1458.734690
# COR                      Cencora             Health Care                      Health Care Distributors                 NaN            1985  2001-08-30   62950211584    1159.010981
# FDX                        FedEx             Industrials                       Air Freight & Logistics                 NaN            1971  1980-12-31   56110206976     684.918622
# CAH              Cardinal Health             Health Care                      Health Care Distributors                 NaN            1971  1997-05-27   37160308736     661.930706
# ADSK                    Autodesk  Information Technology                          Application Software                 NaN            1982  1989-12-01   64679579648     591.478109
# SYY                        Sysco        Consumer Staples                             Food Distributors                 NaN            1969  1986-12-31   38237532160     466.767488
# ACN                    Accenture  Information Technology                IT Consulting & Other Services                 NaN            1989  2011-07-06  147834912768     448.091269
# TDY        Teledyne Technologies  Information Technology            Electronic Equipment & Instruments                 NaN            1960  2020-06-22   26363527168     398.913427
# ZBH                Zimmer Biomet             Health Care                         Health Care Equipment                 NaN            1927  2001-08-07   20189941760     397.511237
# IEX             IDEX Corporation             Industrials  Industrial Machinery & Supplies & Components                 NaN            1988  2019-08-09   12521027584     373.837933
# EXPD    Expeditors International             Industrials                       Air Freight & Logistics                 NaN            1979  2007-10-10   16275365888     354.457802
# ULTA                 Ulta Beauty  Consumer Discretionary                        Other Specialty Retail                 NaN            1990  2016-04-18   23921715200     346.249150
# COST                      Costco        Consumer Staples           Consumer Staples Merchandise Retail                 NaN            1976  1993-10-01  414961958912     343.070193
# CPB     Campbell's Company (The)        Consumer Staples                        Packaged Foods & Meats                 NaN            1869  1957-03-04    9187116032     328.848026
# HRL                 Hormel Foods        Consumer Staples                        Packaged Foods & Meats                 NaN            1891  2009-03-04   13216463872     328.363115
# ADBE                  Adobe Inc.  Information Technology                          Application Software                 NaN            1982  1997-05-05  139502632960     321.391810
# ZTS                       Zoetis             Health Care                               Pharmaceuticals                 NaN            1952  2013-06-21   63845011456     298.550816
# GEN                  Gen Digital  Information Technology                              Systems Software                 NaN            1982  2003-03-25   16332849152     275.925814
# JBL                        Jabil  Information Technology             Electronic Manufacturing Services                 NaN            1966  2023-12-18   22365327360     271.123769
#
#                              Gross Margins (latest→older)
# Ticker
# HD      [0.33874769612698574, 0.3375537928459609, 0.33...
# LOW     [0.3360661615316586, 0.336316380517962, 0.3345...
# COR     [0.033803729619761864, 0.03423854831716707, 0....
# FDX     [0.21603393762937015, 0.2161175920540978, 0.21...
# CAH     [0.038161902793627404, 0.034563786498080035, 0...
# ADSK    [0.9270918284129832, 0.9246861924686193, 0.926...
# SYY     [0.1839621482118717, 0.18527725635431994, 0.18...
# ACN     [0.32609352953344267, 0.32336675596647696, 0.3...
# TDY     [0.44915343915343914, 0.45410345133528524, 0.4...
# ZBH     [0.7673013309717918, 0.7709556138595115, 0.766...
# IEX     [0.4421194322075379, 0.44194996792815905, 0.44...
# EXPD    [0.12726174152859554, 0.1339205665309335, 0.12...
# ULTA    [0.3884018579180984, 0.3909147455012147, 0.396...
# COST    [0.1261333134213391, 0.12259688802674482, 0.12...
# CPB     [0.3399005169218765, 0.3433997509339975, 0.347...
# HRL     [0.16963110771872048, 0.16513950029768762, 0.1...
# ADBE    [0.9223436410137177, 0.9149878922149518, 0.916...
# ZTS     [0.7447061365600691, 0.7402855805243446, 0.735...
# GEN     [0.8650571791613723, 0.8739473684210526, 0.869...
# JBL     [0.1153619776339023, 0.10829347011699614, 0.10...
#
# Saved to sp500_pricing_power.csv  (rows: 389)

# %%
Bloomberg_PricingPower = pd.read_csv("GPM_original.csv")

Bloomberg_PricingPower.sort_values(by="Pricing Power", ascending=False, inplace=True)
Bloomberg_PricingPower
# Out:
#     Ticker                       Full Name  Founding Year  Founded (Wiki)  Date Added    Market Cap  Pricing Power                                      Gross Margins
# 0       HD                Home Depot (The)            NaN            1978  1988-03-31  363708055552    1485.287286  [0.33874769612698574, 0.3375537928459609, 0.33...
# 1      LOW                          Lowe's            NaN  1904/1946/1959  1984-02-29  127428263936    1458.734690  [0.3360661615316586, 0.336316380517962, 0.3345...
# 2      COR                         Cencora            NaN            1985  2001-08-30   56281374720    1159.010981  [0.033803729619761864, 0.03423854831716707, 0....
# 3       MA                      Mastercard            NaN            1966  2008-07-18  508658647040     776.223535  [0.7630915610466148, 0.7600605625946291, 0.763...
# 4      FDX                           FedEx            NaN            1971  1980-12-31   52922630144     705.404925  [0.2161175920540978, 0.2125894293161777, 0.215...
# ..     ...                             ...            ...             ...         ...           ...            ...                                                ...
# 444     MU               Micron Technology            NaN            1978  1994-09-27   91126661120       4.803668  [0.22352753773246783, -0.09111969111969112, 0....
# 445    EXE                   Expand Energy            NaN            1989  2025-03-24   25015162880       4.003942  [0.2703150912106136, 0.6481028938906752, 0.712...
# 446    RCL           Royal Caribbean Group            NaN            1997  2014-12-05   62270062592       1.935326  [0.4751592356687898, 0.44064748201438847, 0.25...
# 447   NCLH  Norwegian Cruise Line Holdings            NaN     2011 (1966)  2017-10-13    7751153152       1.348033  [0.40868856880912596, 0.36912667293884716, 0.1...
# 448    CCL                        Carnival            NaN            1972  1998-12-22   26609451008       1.346029  [0.37500499580352503, 0.3369610521928403, 0.03...
#
# [449 rows x 8 columns]

# %% [markdown]
# ### Modification of the bloomberg measurement for smoothness

# %%
# Pricing Power on S&P 500 — robust fetch + selectable metric
# Fixes Wikipedia 403, normalizes tickers, handles yfinance fallbacks, and caches constituents.

# ---------- 0) AUTO-INSTALL DEPENDENCIES ----------
import sys, subprocess, importlib

REQUIRED_PACKAGES = [
    "yfinance",
    "pandas",
    "numpy",
    "lxml",
    "beautifulsoup4",
    "html5lib",
    "requests",
]

def ensure_packages(pkgs):
    for p in pkgs:
        try:
            importlib.import_module(p if p != "beautifulsoup4" else "bs4")
        except ImportError:
            print(f"Installing missing package: {p} …")
            subprocess.check_call([sys.executable, "-m", "pip", "install", p])

ensure_packages(REQUIRED_PACKAGES)

# ---------- 1) IMPORTS ----------
import os, io, re, time, math, requests
import numpy as np
import pandas as pd
import yfinance as yf
from typing import Optional, List, Dict, Tuple

# ---------- 2) CONFIG ----------
METRIC = "changes"     # <- choose: "level", "changes", "uptrend"
MAX_YEARS = 5          # use up to N most recent annual margins
SLEEP_SEC = 0.5        # throttle per ticker
RETRY_N = 2            # retries for transient errors
EXCLUDE_FINANCIALS = False   # set True to exclude Financials/Real Estate
OUTPUT_CSV = f"sp500_pricing_power_{METRIC}.csv"

UA = ("Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
      "AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.1 Safari/537.36")
CACHE_PATH = "sp500_constituents_cache.csv"

# ---------- 3) ROBUST S&P500 FETCH (handles 403 + fallback + cache) ----------
def load_cached_sp500(path=CACHE_PATH):
    if os.path.exists(path):
        try:
            df = pd.read_csv(path)
            if {"Ticker", "Full Name"}.issubset(df.columns):
                return df
        except Exception:
            pass
    return None

def save_cache(df, path=CACHE_PATH):
    try:
        df.to_csv(path, index=False)
    except Exception:
        pass

def fetch_sp500_wikipedia() -> pd.DataFrame:
    wiki = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    # A) direct with User-Agent via pandas
    try:
        tables = pd.read_html(wiki, storage_options={"User-Agent": UA})
        if tables:
            return tables[0]
    except Exception:
        pass
    # B) requests + read_html
    with requests.Session() as s:
        s.headers.update({"User-Agent": UA})
        r = s.get(wiki, timeout=20)
        r.raise_for_status()
        tables = pd.read_html(r.text)
        if tables:
            return tables[0]
    raise RuntimeError("Wikipedia fetch failed.")

def fetch_sp500_fallback_csv() -> pd.DataFrame:
    url_csv = "https://raw.githubusercontent.com/datasets/s-and-p-500-companies/master/data/constituents.csv"
    with requests.Session() as s:
        s.headers.update({"User-Agent": UA})
        r = s.get(url_csv, timeout=20)
        r.raise_for_status()
        return pd.read_csv(io.StringIO(r.text))

def get_sp500_constituents() -> pd.DataFrame:
    cached = load_cached_sp500()
    if cached is not None:
        print(f"Loaded constituents from cache ({len(cached)} rows).")
        return cached

    try:
        df = fetch_sp500_wikipedia()
        source = "wikipedia"
    except Exception:
        df = fetch_sp500_fallback_csv()
        source = "fallback_csv"

    df.columns = [c.strip() for c in df.columns]
    rename_map = {
        "Symbol": "Ticker",
        "Security": "Full Name",
        "GICS Sector": "Sector",
        "GICS Sub-Industry": "Sub-Industry",
        "Date added": "Date Added",
        "Founded": "Founded (Wiki)",
    }
    for old, new in rename_map.items():
        if old in df.columns:
            df = df.rename(columns={old: new})

    for col in ["Ticker", "Full Name", "Sector", "Sub-Industry", "Date Added", "Founded (Wiki)"]:
        if col not in df.columns:
            df[col] = np.nan

    # yfinance class shares: BRK.B -> BRK-B
    df["Ticker"] = df["Ticker"].astype(str).str.replace(".", "-", regex=False).str.strip()

    df = df[["Ticker", "Full Name", "Sector", "Sub-Industry", "Date Added", "Founded (Wiki)"]].copy()

    save_cache(df)
    print(f"S&P 500 table loaded from: {source} (rows: {len(df)})")
    return df

# ---------- 4) YFINANCE HELPERS ----------
def find_label(idx: pd.Index, candidates: List[str]) -> Optional[str]:
    s = idx.to_series().astype(str)
    for cand in candidates:
        mask = s.str.contains(cand, case=False, na=False)
        if mask.any():
            return s[mask].index[0]
    return None

def get_income_stmt(tkr: yf.Ticker) -> Optional[pd.DataFrame]:
    for attr in ("income_stmt", "financials"):
        df = getattr(tkr, attr, None)
        if isinstance(df, pd.DataFrame) and not df.empty:
            return df
    try:
        df = tkr.get_income_stmt()
        if isinstance(df, pd.DataFrame) and not df.empty:
            return df
    except Exception:
        pass
    return None

def safe_info(tkr: yf.Ticker, key: str):
    try:
        info = tkr.info
        return info.get(key, np.nan) if isinstance(info, dict) else np.nan
    except Exception:
        return np.nan

# ---------- 5) METRIC FUNCTIONS ----------
def metric_level(margins: List[float]) -> Dict[str, float]:
    sd = float(np.std(margins, ddof=0))
    score = (1.0 / sd) if sd != 0 else float("inf")
    return {"Score": score, "Std_Lvl": sd}

def metric_changes(margins: List[float]) -> Dict[str, float]:
    if len(margins) < 3:
        # prefer ≥3 margins → ≥2 changes for a meaningful std
        pass
    changes = np.diff(margins)
    sd = float(np.std(changes, ddof=0)) if len(changes) > 0 else float("inf")
    score = (1.0 / sd) if sd != 0 else float("inf")
    return {"Score": score, "Std_Delta": sd, "Deltas": changes.tolist()}

def metric_uptrend(margins: List[float]) -> Dict[str, float]:
    # Linear trend fit: latest->older indexed as t=0,1,2,...
    y = np.array(margins, dtype=float)
    n = len(y)
    t = np.arange(n, dtype=float)
    # np.polyfit returns slope, intercept (degree=1)
    slope, intercept = np.polyfit(t, y, 1)
    y_hat = intercept + slope * t
    resid = y - y_hat
    resid_std = float(np.std(resid, ddof=0))
    ss_res = float(np.sum(resid**2))
    ss_tot = float(np.sum((y - y.mean())**2)) if n > 1 else 0.0
    r2 = 1.0 - ss_res/ss_tot if ss_tot > 0 else 1.0
    score = max(float(slope), 0.0) / (resid_std + 1e-6)
    return {"Score": score, "Slope": float(slope), "ResidStd": resid_std, "R2": r2}

def score_from_margins(margins: List[float]) -> Dict[str, float]:
    if METRIC == "level":
        return metric_level(margins)
    elif METRIC == "changes":
        return metric_changes(margins)
    elif METRIC == "uptrend":
        return metric_uptrend(margins)
    else:
        raise ValueError("METRIC must be one of: 'level', 'changes', 'uptrend'")

# ---------- 6) MAIN COLLECTOR ----------
def collect_record(row: pd.Series, n_years:int=MAX_YEARS) -> Optional[Dict]:
    ticker = row["Ticker"]
    last_err = None

    for attempt in range(1, RETRY_N + 2):
        try:
            t = yf.Ticker(ticker)
            fin = get_income_stmt(t)
            if fin is None or fin.empty:
                last_err = "no financials"
                break

            # Find revenue & COGS
            rev_label  = find_label(fin.index, ["total revenue", "revenue"])
            cogs_label = find_label(fin.index, ["cost of revenue", "cost of goods sold", "cost revenue"])
            if not rev_label or not cogs_label:
                last_err = f"missing rows → rev={rev_label}, cogs={cogs_label}"
                break

            revenue = fin.loc[rev_label].dropna()
            cogs    = fin.loc[cogs_label].dropna()
            cols = [c for c in revenue.index if c in cogs.index]
            if not cols:
                last_err = "no overlapping revenue/COGS columns"
                break
            # newest -> older if possible
            try:
                cols = sorted(cols, reverse=True)
            except Exception:
                pass

            margins, used_cols = [], []
            for c in cols:
                r, cg = revenue[c], cogs[c]
                if pd.notna(r) and pd.notna(cg) and r not in (0, 0.0):
                    gm = (r - cg) / r
                    if isinstance(gm, (int, float)) and math.isfinite(gm) and -5.0 < gm < 5.0:
                        margins.append(float(gm))
                        used_cols.append(str(c))
                if len(margins) >= n_years:
                    break

            # minimal data requirements
            min_needed = 2 if METRIC == "level" else 3  # level needs ≥2; others ≥3 recommended
            if len(margins) < min_needed:
                last_err = f"only {len(margins)} margins"
                break

            score_parts = score_from_margins(margins)

            return {
                "Ticker": ticker,
                "Full Name": row.get("Full Name", np.nan),
                "Sector": row.get("Sector", np.nan),
                "Sub-Industry": row.get("Sub-Industry", np.nan),
                "Date Added": row.get("Date Added", np.nan),
                "Founded (Wiki)": row.get("Founded (Wiki)", np.nan),
                "Market Cap": safe_info(t, "marketCap"),
                "Founding Year (YF)": safe_info(t, "founded"),
                "Gross Margins (newest→older)": margins,
                "Years Used (labels)": used_cols,
                **score_parts,
            }
        except Exception as e:
            last_err = str(e)

        time.sleep(SLEEP_SEC * attempt)

    print(f"  ❌ {ticker}: {last_err}")
    return None

# ---------- 7) RUN PIPELINE ----------
sp500 = get_sp500_constituents()

if EXCLUDE_FINANCIALS and "Sector" in sp500.columns:
    sp500 = sp500[~sp500["Sector"].isin({"Financials", "Real Estate"})].copy()

results: List[Dict] = []
n = len(sp500)
for i, row in sp500.reset_index(drop=True).iterrows():
    print(f"Processing {row['Ticker']}  ({i+1}/{n}) …")
    rec = collect_record(row)
    if rec:
        results.append(rec)
    time.sleep(SLEEP_SEC)

# ---------- 8) OUTPUT ----------
if results:
    GPM_smooth = pd.DataFrame(results).set_index("Ticker")
    base_cols = [
        "Full Name", "Sector", "Sub-Industry",
        "Founding Year (YF)", "Founded (Wiki)", "Date Added",
        "Market Cap", "Gross Margins (newest→older)", "Years Used (labels)"
    ]

    if METRIC == "level":
        order = base_cols + ["Score", "Std_Lvl"]
    elif METRIC == "changes":
        order = base_cols + ["Score", "Std_Delta", "Deltas"]
    else:  # uptrend
        order = base_cols + ["Score", "Slope", "ResidStd", "R2"]
# Out:
# Loaded constituents from cache (503 rows).
# Processing MMM  (1/503) …
# Processing AOS  (2/503) …
# Processing ABT  (3/503) …
# Processing ABBV  (4/503) …
# Processing ACN  (5/503) …
# Processing ADBE  (6/503) …
# Processing AMD  (7/503) …
# Processing AES  (8/503) …
# Processing AFL  (9/503) …
#   ❌ AFL: missing rows → rev=Total Revenue, cogs=None
# Processing A  (10/503) …
# Processing APD  (11/503) …
# Processing ABNB  (12/503) …
# Processing AKAM  (13/503) …
# Processing ALB  (14/503) …
# Processing ARE  (15/503) …
# Processing ALGN  (16/503) …
# Processing ALLE  (17/503) …
# Processing LNT  (18/503) …
# Processing ALL  (19/503) …
#   ❌ ALL: missing rows → rev=Total Revenue, cogs=None
# Processing GOOGL  (20/503) …
# Processing GOOG  (21/503) …
# Processing MO  (22/503) …
# Processing AMZN  (23/503) …
# Processing AMCR  (24/503) …
# Processing AEE  (25/503) …
# Processing AEP  (26/503) …
# Processing AXP  (27/503) …
#   ❌ AXP: missing rows → rev=Total Revenue, cogs=None
# Processing AIG  (28/503) …
#   ❌ AIG: missing rows → rev=Total Revenue, cogs=None
# Processing AMT  (29/503) …
# Processing AWK  (30/503) …
# Processing AMP  (31/503) …
#   ❌ AMP: missing rows → rev=Total Revenue, cogs=None
# Processing AME  (32/503) …
# Processing AMGN  (33/503) …
# Processing APH  (34/503) …
# Processing ADI  (35/503) …
# Processing AON  (36/503) …
# Processing APA  (37/503) …
# Processing APO  (38/503) …
# Processing AAPL  (39/503) …
# Processing AMAT  (40/503) …
# Processing APP  (41/503) …
# Processing APTV  (42/503) …
# Processing ACGL  (43/503) …
#   ❌ ACGL: missing rows → rev=Total Revenue, cogs=None
# Processing ADM  (44/503) …
# Processing ANET  (45/503) …
# Processing AJG  (46/503) …
# Processing AIZ  (47/503) …
#   ❌ AIZ: missing rows → rev=Total Revenue, cogs=None
# Processing T  (48/503) …
# Processing ATO  (49/503) …
# Processing ADSK  (50/503) …
# Processing ADP  (51/503) …
# Processing AZO  (52/503) …
# Processing AVB  (53/503) …
# Processing AVY  (54/503) …
# Processing AXON  (55/503) …
# Processing BKR  (56/503) …
# Processing BALL  (57/503) …
# Processing BAC  (58/503) …
#   ❌ BAC: missing rows → rev=Total Revenue, cogs=None
# Processing BAX  (59/503) …
# Processing BDX  (60/503) …
# Processing BRK-B  (61/503) …
#   ❌ BRK-B: missing rows → rev=Total Revenue, cogs=None
# Processing BBY  (62/503) …
# Processing TECH  (63/503) …
# Processing BIIB  (64/503) …
# Processing BLK  (65/503) …
# Processing BX  (66/503) …
#   ❌ BX: missing rows → rev=Total Revenue, cogs=None
# Processing XYZ  (67/503) …
# Processing BK  (68/503) …
#   ❌ BK: missing rows → rev=Total Revenue, cogs=None
# Processing BA  (69/503) …
# Processing BKNG  (70/503) …
#   ❌ BKNG: missing rows → rev=Total Revenue, cogs=None
# Processing BSX  (71/503) …
# Processing BMY  (72/503) …
# Processing AVGO  (73/503) …
# Processing BR  (74/503) …
# Processing BRO  (75/503) …
# Processing BF-B  (76/503) …
# Processing BLDR  (77/503) …
# Processing BG  (78/503) …
# Processing BXP  (79/503) …
# Processing CHRW  (80/503) …
# Processing CDNS  (81/503) …
# Processing CPT  (82/503) …
# Processing CPB  (83/503) …
# Processing COF  (84/503) …
#   ❌ COF: missing rows → rev=Total Revenue, cogs=None
# Processing CAH  (85/503) …
# Processing KMX  (86/503) …
# Processing CCL  (87/503) …
# Processing CARR  (88/503) …
# Processing CAT  (89/503) …
# Processing CBOE  (90/503) …
# Processing CBRE  (91/503) …
# Processing CDW  (92/503) …
# Processing COR  (93/503) …
# Processing CNC  (94/503) …
# Processing CNP  (95/503) …
# Processing CF  (96/503) …
# Processing CRL  (97/503) …
# Processing SCHW  (98/503) …
#   ❌ SCHW: missing rows → rev=Total Revenue, cogs=None
# Processing CHTR  (99/503) …
# Processing CVX  (100/503) …
# Processing CMG  (101/503) …
# Processing CB  (102/503) …
#   ❌ CB: missing rows → rev=Total Revenue, cogs=None
# Processing CHD  (103/503) …
# Processing CI  (104/503) …
#   ❌ CI: missing rows → rev=Total Revenue, cogs=None
# Processing CINF  (105/503) …
#   ❌ CINF: missing rows → rev=Total Revenue, cogs=None
# Processing CTAS  (106/503) …
# Processing CSCO  (107/503) …
# Processing C  (108/503) …
#   ❌ C: missing rows → rev=Total Revenue, cogs=None
# Processing CFG  (109/503) …
#   ❌ CFG: missing rows → rev=Total Revenue, cogs=None
# Processing CLX  (110/503) …
# Processing CME  (111/503) …
# Processing CMS  (112/503) …
# Processing KO  (113/503) …
# Processing CTSH  (114/503) …
# Processing COIN  (115/503) …
# Processing CL  (116/503) …
# Processing CMCSA  (117/503) …
# Processing CAG  (118/503) …
# Processing COP  (119/503) …
# Processing ED  (120/503) …
# Processing STZ  (121/503) …
# Processing CEG  (122/503) …
# Processing COO  (123/503) …
# Processing CPRT  (124/503) …
# Processing GLW  (125/503) …
# Processing CPAY  (126/503) …
# Processing CTVA  (127/503) …
# Processing CSGP  (128/503) …
# Processing COST  (129/503) …
# Processing CTRA  (130/503) …
# Processing CRWD  (131/503) …
# Processing CCI  (132/503) …
# Processing CSX  (133/503) …
# Processing CMI  (134/503) …
# Processing CVS  (135/503) …
# Processing DHR  (136/503) …
# Processing DRI  (137/503) …
# Processing DDOG  (138/503) …
# Processing DVA  (139/503) …
# Processing DAY  (140/503) …
# Processing DECK  (141/503) …
# Processing DE  (142/503) …
# Processing DELL  (143/503) …
# Processing DAL  (144/503) …
# Processing DVN  (145/503) …
# Processing DXCM  (146/503) …
# Processing FANG  (147/503) …
# Processing DLR  (148/503) …
# Processing DG  (149/503) …
# Processing DLTR  (150/503) …
# Processing D  (151/503) …
# Processing DPZ  (152/503) …
# Processing DASH  (153/503) …
# Processing DOV  (154/503) …
# Processing DOW  (155/503) …
# Processing DHI  (156/503) …
# Processing DTE  (157/503) …
# Processing DUK  (158/503) …
# Processing DD  (159/503) …
# Processing EMN  (160/503) …
# Processing ETN  (161/503) …
# Processing EBAY  (162/503) …
# Processing ECL  (163/503) …
# Processing EIX  (164/503) …
# Processing EW  (165/503) …
# Processing EA  (166/503) …
# Processing ELV  (167/503) …
#   ❌ ELV: missing rows → rev=Total Revenue, cogs=None
# Processing EME  (168/503) …
# Processing EMR  (169/503) …
# Processing ETR  (170/503) …
# Processing EOG  (171/503) …
# Processing EPAM  (172/503) …
# Processing EQT  (173/503) …
# Processing EFX  (174/503) …
# Processing EQIX  (175/503) …
# Processing EQR  (176/503) …
# Processing ERIE  (177/503) …
#   ❌ ERIE: missing rows → rev=Total Revenue, cogs=None
# Processing ESS  (178/503) …
# Processing EL  (179/503) …
# Processing EG  (180/503) …
#   ❌ EG: missing rows → rev=Total Revenue, cogs=None
# Processing EVRG  (181/503) …
# Processing ES  (182/503) …
# Processing EXC  (183/503) …
# Processing EXE  (184/503) …
# Processing EXPE  (185/503) …
# Processing EXPD  (186/503) …
# Processing EXR  (187/503) …
# Processing XOM  (188/503) …
# Processing FFIV  (189/503) …
# Processing FDS  (190/503) …
# Processing FICO  (191/503) …
# Processing FAST  (192/503) …
# Processing FRT  (193/503) …
# Processing FDX  (194/503) …
# Processing FIS  (195/503) …
# Processing FITB  (196/503) …
#   ❌ FITB: missing rows → rev=Total Revenue, cogs=None
# Processing FSLR  (197/503) …
# Processing FE  (198/503) …
# Processing FI  (199/503) …
# Processing F  (200/503) …
# Processing FTNT  (201/503) …
# Processing FTV  (202/503) …
# Processing FOXA  (203/503) …
#   ❌ FOXA: missing rows → rev=Total Revenue, cogs=None
# Processing FOX  (204/503) …
#   ❌ FOX: missing rows → rev=Total Revenue, cogs=None
# Processing BEN  (205/503) …
# Processing FCX  (206/503) …
# Processing GRMN  (207/503) …
# Processing IT  (208/503) …
# Processing GE  (209/503) …
# Processing GEHC  (210/503) …
# Processing GEV  (211/503) …
# Processing GEN  (212/503) …
# Processing GNRC  (213/503) …
# Processing GD  (214/503) …
# Processing GIS  (215/503) …
# Processing GM  (216/503) …
# Processing GPC  (217/503) …
# Processing GILD  (218/503) …
# Processing GPN  (219/503) …
# Processing GL  (220/503) …
#   ❌ GL: missing rows → rev=Total Revenue, cogs=None
# Processing GDDY  (221/503) …
# Processing GS  (222/503) …
#   ❌ GS: missing rows → rev=Total Revenue, cogs=None
# Processing HAL  (223/503) …
# Processing HIG  (224/503) …
#   ❌ HIG: missing rows → rev=Total Revenue, cogs=None
# Processing HAS  (225/503) …
# Processing HCA  (226/503) …
# Processing DOC  (227/503) …
# Processing HSIC  (228/503) …
# Processing HSY  (229/503) …
# Processing HPE  (230/503) …
# Processing HLT  (231/503) …
# Processing HOLX  (232/503) …
# Processing HD  (233/503) …
# Processing HON  (234/503) …
# Processing HRL  (235/503) …
# Processing HST  (236/503) …
# Processing HWM  (237/503) …
# Processing HPQ  (238/503) …
# Processing HUBB  (239/503) …
# Processing HUM  (240/503) …
#   ❌ HUM: missing rows → rev=Total Revenue, cogs=None
# Processing HBAN  (241/503) …
#   ❌ HBAN: missing rows → rev=Total Revenue, cogs=None
# Processing HII  (242/503) …
# Processing IBM  (243/503) …
# Processing IEX  (244/503) …
# Processing IDXX  (245/503) …
# Processing ITW  (246/503) …
# Processing INCY  (247/503) …
# Processing IR  (248/503) …
# Processing PODD  (249/503) …
# Processing INTC  (250/503) …
# Processing IBKR  (251/503) …
# Processing ICE  (252/503) …
# Processing IFF  (253/503) …
# Processing IP  (254/503) …
# Processing IPG  (255/503) …
# Processing INTU  (256/503) …
# Processing ISRG  (257/503) …
# Processing IVZ  (258/503) …
# Processing INVH  (259/503) …
# Processing IQV  (260/503) …
# Processing IRM  (261/503) …
# Processing JBHT  (262/503) …
# Processing JBL  (263/503) …
# Processing JKHY  (264/503) …
# Processing J  (265/503) …
# Processing JNJ  (266/503) …
# Processing JCI  (267/503) …
# Processing JPM  (268/503) …
#   ❌ JPM: missing rows → rev=Total Revenue, cogs=None
# Processing K  (269/503) …
# Processing KVUE  (270/503) …
# Processing KDP  (271/503) …
# Processing KEY  (272/503) …
#   ❌ KEY: missing rows → rev=Total Revenue, cogs=None
# Processing KEYS  (273/503) …
# Processing KMB  (274/503) …
# Processing KIM  (275/503) …
# Processing KMI  (276/503) …
# Processing KKR  (277/503) …
# Processing KLAC  (278/503) …
# Processing KHC  (279/503) …
# Processing KR  (280/503) …
# Processing LHX  (281/503) …
# Processing LH  (282/503) …
# Processing LRCX  (283/503) …
# Processing LW  (284/503) …
# Processing LVS  (285/503) …
# Processing LDOS  (286/503) …
# Processing LEN  (287/503) …
# Processing LII  (288/503) …
# Processing LLY  (289/503) …
# Processing LIN  (290/503) …
# Processing LYV  (291/503) …
# Processing LKQ  (292/503) …
# Processing LMT  (293/503) …
# Processing L  (294/503) …
#   ❌ L: missing rows → rev=Total Revenue, cogs=None
# Processing LOW  (295/503) …
# Processing LULU  (296/503) …
# Processing LYB  (297/503) …
# Processing MTB  (298/503) …
#   ❌ MTB: missing rows → rev=Total Revenue, cogs=None
# Processing MPC  (299/503) …
# Processing MAR  (300/503) …
# Processing MMC  (301/503) …
# Processing MLM  (302/503) …
# Processing MAS  (303/503) …
# Processing MA  (304/503) …
# Processing MTCH  (305/503) …
# Processing MKC  (306/503) …
# Processing MCD  (307/503) …
# Processing MCK  (308/503) …
# Processing MDT  (309/503) …
# Processing MRK  (310/503) …
# Processing META  (311/503) …
# Processing MET  (312/503) …
#   ❌ MET: missing rows → rev=Total Revenue, cogs=None
# Processing MTD  (313/503) …
# Processing MGM  (314/503) …
# Processing MCHP  (315/503) …
# Processing MU  (316/503) …
# Processing MSFT  (317/503) …
# Processing MAA  (318/503) …
# Processing MRNA  (319/503) …
# Processing MHK  (320/503) …
# Processing MOH  (321/503) …
# Processing TAP  (322/503) …
# Processing MDLZ  (323/503) …
# Processing MPWR  (324/503) …
# Processing MNST  (325/503) …
# Processing MCO  (326/503) …
# Processing MS  (327/503) …
#   ❌ MS: missing rows → rev=Total Revenue, cogs=None
# Processing MOS  (328/503) …
# Processing MSI  (329/503) …
# Processing MSCI  (330/503) …
# Processing NDAQ  (331/503) …
# Processing NTAP  (332/503) …
# Processing NFLX  (333/503) …
# Processing NEM  (334/503) …
# Processing NWSA  (335/503) …
#   ❌ NWSA: missing rows → rev=Total Revenue, cogs=None
# Processing NWS  (336/503) …
#   ❌ NWS: missing rows → rev=Total Revenue, cogs=None
# Processing NEE  (337/503) …
# Processing NKE  (338/503) …
# Processing NI  (339/503) …
# Processing NDSN  (340/503) …
# Processing NSC  (341/503) …
# Processing NTRS  (342/503) …
#   ❌ NTRS: missing rows → rev=Total Revenue, cogs=None
# Processing NOC  (343/503) …
# Processing NCLH  (344/503) …
# Processing NRG  (345/503) …
# Processing NUE  (346/503) …
# Processing NVDA  (347/503) …
# Processing NVR  (348/503) …
# Processing NXPI  (349/503) …
# Processing ORLY  (350/503) …
# Processing OXY  (351/503) …
# Processing ODFL  (352/503) …
# Processing OMC  (353/503) …
# Processing ON  (354/503) …
# Processing OKE  (355/503) …
# Processing ORCL  (356/503) …
# Processing OTIS  (357/503) …
# Processing PCAR  (358/503) …
# Processing PKG  (359/503) …
# Processing PLTR  (360/503) …
# Processing PANW  (361/503) …
# Processing PSKY  (362/503) …
# Processing PH  (363/503) …
# Processing PAYX  (364/503) …
# Processing PAYC  (365/503) …
# Processing PYPL  (366/503) …
# Processing PNR  (367/503) …
# Processing PEP  (368/503) …
# Processing PFE  (369/503) …
# Processing PCG  (370/503) …
# Processing PM  (371/503) …
# Processing PSX  (372/503) …
# Processing PNW  (373/503) …
# Processing PNC  (374/503) …
#   ❌ PNC: missing rows → rev=Total Revenue, cogs=None
# Processing POOL  (375/503) …
# Processing PPG  (376/503) …
# Processing PPL  (377/503) …
# Processing PFG  (378/503) …
#   ❌ PFG: missing rows → rev=Total Revenue, cogs=None
# Processing PG  (379/503) …
# Processing PGR  (380/503) …
#   ❌ PGR: missing rows → rev=Total Revenue, cogs=None
# Processing PLD  (381/503) …
# Processing PRU  (382/503) …
#   ❌ PRU: missing rows → rev=Total Revenue, cogs=None
# Processing PEG  (383/503) …
# Processing PTC  (384/503) …
# Processing PSA  (385/503) …
# Processing PHM  (386/503) …
# Processing PWR  (387/503) …
# Processing QCOM  (388/503) …
# Processing DGX  (389/503) …
# Processing RL  (390/503) …
# Processing RJF  (391/503) …
#   ❌ RJF: missing rows → rev=Total Revenue, cogs=None
# Processing RTX  (392/503) …
# Processing O  (393/503) …
# Processing REG  (394/503) …
# Processing REGN  (395/503) …
# Processing RF  (396/503) …
#   ❌ RF: missing rows → rev=Total Revenue, cogs=None
# Processing RSG  (397/503) …
# Processing RMD  (398/503) …
# Processing RVTY  (399/503) …
# Processing HOOD  (400/503) …
# Processing ROK  (401/503) …
# Processing ROL  (402/503) …
# Processing ROP  (403/503) …
# Processing ROST  (404/503) …
# Processing RCL  (405/503) …
# Processing SPGI  (406/503) …
# Processing CRM  (407/503) …
# Processing SBAC  (408/503) …
# Processing SLB  (409/503) …
# Processing STX  (410/503) …
# Processing SRE  (411/503) …
# Processing NOW  (412/503) …
# Processing SHW  (413/503) …
# Processing SPG  (414/503) …
# Processing SWKS  (415/503) …
# Processing SJM  (416/503) …
# Processing SW  (417/503) …
# Processing SNA  (418/503) …
# Processing SOLV  (419/503) …
# Processing SO  (420/503) …
# Processing LUV  (421/503) …
# Processing SWK  (422/503) …
# Processing SBUX  (423/503) …
# Processing STT  (424/503) …
#   ❌ STT: missing rows → rev=Total Revenue, cogs=None
# Processing STLD  (425/503) …
# Processing STE  (426/503) …
# Processing SYK  (427/503) …
# Processing SMCI  (428/503) …
# Processing SYF  (429/503) …
#   ❌ SYF: missing rows → rev=Total Revenue, cogs=None
# Processing SNPS  (430/503) …
# Processing SYY  (431/503) …
# Processing TMUS  (432/503) …
# Processing TROW  (433/503) …
# Processing TTWO  (434/503) …
# Processing TPR  (435/503) …
# Processing TRGP  (436/503) …
# Processing TGT  (437/503) …
# Processing TEL  (438/503) …
# Processing TDY  (439/503) …
# Processing TER  (440/503) …
# Processing TSLA  (441/503) …
# Processing TXN  (442/503) …
# Processing TPL  (443/503) …
# Processing TXT  (444/503) …
# Processing TMO  (445/503) …
# Processing TJX  (446/503) …
# Processing TKO  (447/503) …
# Processing TTD  (448/503) …
# Processing TSCO  (449/503) …
# Processing TT  (450/503) …
# Processing TDG  (451/503) …
# Processing TRV  (452/503) …
#   ❌ TRV: missing rows → rev=Total Revenue, cogs=None
# Processing TRMB  (453/503) …
# Processing TFC  (454/503) …
#   ❌ TFC: missing rows → rev=Total Revenue, cogs=None
# Processing TYL  (455/503) …
# Processing TSN  (456/503) …
# Processing USB  (457/503) …
#   ❌ USB: missing rows → rev=Total Revenue, cogs=None
# Processing UBER  (458/503) …
# Processing UDR  (459/503) …
# Processing ULTA  (460/503) …
# Processing UNP  (461/503) …
# Processing UAL  (462/503) …
# Processing UPS  (463/503) …
# Processing URI  (464/503) …
# Processing UNH  (465/503) …
# Processing UHS  (466/503) …
# Processing VLO  (467/503) …
# Processing VTR  (468/503) …
# Processing VLTO  (469/503) …
# Processing VRSN  (470/503) …
# Processing VRSK  (471/503) …
# Processing VZ  (472/503) …
# Processing VRTX  (473/503) …
# Processing VTRS  (474/503) …
# Processing VICI  (475/503) …
# Processing V  (476/503) …
# Processing VST  (477/503) …
# Processing VMC  (478/503) …
# Processing WRB  (479/503) …
#   ❌ WRB: missing rows → rev=Total Revenue, cogs=None
# Processing GWW  (480/503) …
# Processing WAB  (481/503) …
# Processing WMT  (482/503) …
# Processing DIS  (483/503) …
# Processing WBD  (484/503) …
# Processing WM  (485/503) …
# Processing WAT  (486/503) …
# Processing WEC  (487/503) …
# Processing WFC  (488/503) …
#   ❌ WFC: missing rows → rev=Total Revenue, cogs=None
# Processing WELL  (489/503) …
# Processing WST  (490/503) …
# Processing WDC  (491/503) …
# Processing WY  (492/503) …
# Processing WSM  (493/503) …
# Processing WMB  (494/503) …
# Processing WTW  (495/503) …
# Processing WDAY  (496/503) …
# Processing WYNN  (497/503) …
# Processing XEL  (498/503) …
# Processing XYL  (499/503) …
# Processing YUM  (500/503) …
# Processing ZBRA  (501/503) …
# Processing ZBH  (502/503) …
# Processing ZTS  (503/503) …
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 303
#     300     order = base_cols + ["Score", "Slope", "ResidStd", "R2"]
#     302 GPM_smooth = GPM_smooth.reindex(columns=order)
# --> 303 GPM_smooth = GPM_smoothf.sort_values("Score", ascending=False)
#     305 pd.set_option("display.width", 200)
#     306 pd.set_option("display.max_rows", 60)
#
# NameError: name 'GPM_smoothf' is not defined

# %%
GPM_smooth = GPM_smooth.reindex(columns=order)
GPM_smooth = GPM_smooth.sort_values("Score", ascending=False)

pd.set_option("display.width", 200)
pd.set_option("display.max_rows", 60)
print(GPM_smooth.head(20))
# Out:
#                         Full Name                  Sector                         Sub-Industry  Founding Year (YF)  Founded (Wiki)  Date Added    Market Cap  \
# Ticker
# MCK          McKesson Corporation             Health Care             Health Care Distributors                 NaN            1833  1999-01-13   94973698048
# HD               Home Depot (The)  Consumer Discretionary              Home Improvement Retail                 NaN            1978  1988-03-31  374016507904
# LOW                        Lowe's  Consumer Discretionary              Home Improvement Retail                 NaN  1904/1946/1959  1984-02-29  130234761216
# COR                       Cencora             Health Care             Health Care Distributors                 NaN            1985  2001-08-30   61653168128
# JCI              Johnson Controls             Industrials                    Building Products                 NaN            1885  2010-08-27   69070381056
# CTAS                       Cintas             Industrials         Diversified Support Services                 NaN            1929  2001-03-01   75534868480
# FAST                     Fastenal             Industrials     Trading Companies & Distributors                 NaN            1967  2008-09-15   52538802176
# KIM                  Kimco Realty             Real Estate                         Retail REITs                 NaN            1958  2006-04-04   14072225792
# WTW          Willis Towers Watson              Financials                    Insurance Brokers                 NaN            2016  2016-01-05   32872697856
# UHS     Universal Health Services             Health Care               Health Care Facilities                 NaN            1979  2014-09-20   12480183296
# VICI              Vici Properties             Real Estate                 Hotel & Resort REITs                 NaN            2017  2022-06-08   33014808576
# SYY                         Sysco        Consumer Staples                    Food Distributors                 NaN            1969  1986-12-31   37538910208
# ROP            Roper Technologies  Information Technology   Electronic Equipment & Instruments                 NaN            1981  2009-12-23   54775435264
# LLY                   Lilly (Eli)             Health Care                      Pharmaceuticals                 NaN            1876  1970-12-31  747187732480
# MTD                Mettler Toledo             Health Care       Life Sciences Tools & Services                 NaN            1945  2016-09-06   26236381184
# ADSK                     Autodesk  Information Technology                 Application Software                 NaN            1982  1989-12-01   64645500928
# DG                 Dollar General        Consumer Staples  Consumer Staples Merchandise Retail                 NaN            1939  2012-12-03   21838921728
# INCY                       Incyte             Health Care                        Biotechnology                 NaN            1991  2017-02-28   16364141568
# HSIC                 Henry Schein             Health Care             Health Care Distributors                 NaN            1932  2015-03-17    7660524544
# VRSN                     Verisign  Information Technology   Internet Services & Infrastructure                 NaN            1995  2006-02-01   24362829824
#
#                              Gross Margins (newest→older)                                Years Used (labels)        Score  Std_Delta                                             Deltas
# Ticker
# MCK     [0.0371061492657032, 0.041521147366410854, 0.0...  [2025-03-31 00:00:00, 2024-03-31 00:00:00, 202...  1241.226334   0.000806  [0.004414998100707654, 0.003139166101431043, 0...
# HD      [0.33874769612698574, 0.3375537928459609, 0.33...  [2025-01-31 00:00:00, 2024-01-31 00:00:00, 202...   989.556275   0.001011  [-0.0011939032810248662, 0.0010547470166846762...
# LOW     [0.3360661615316586, 0.336316380517962, 0.3345...  [2025-01-31 00:00:00, 2024-01-31 00:00:00, 202...   916.298089   0.001091  [0.00025021898630339656, -0.001756988807765092...
# COR     [0.033803729619761864, 0.03423854831716707, 0....  [2024-09-30 00:00:00, 2023-09-30 00:00:00, 202...   739.202957   0.001353  [0.0004348186974052065, 0.000601182225409086, ...
# JCI     [0.35190833042872083, 0.34946934754377323, 0.3...  [2024-09-30 00:00:00, 2023-09-30 00:00:00, 202...   661.040988   0.001513  [-0.0024389828849475936, -0.005911659895374732...
# CTAS    [0.5003939486165667, 0.4883405242369315, 0.473...  [2025-05-31 00:00:00, 2024-05-31 00:00:00, 202...   594.549169   0.001682  [-0.012053424379635247, -0.014942457658735087,...
# FAST    [0.4508216273522396, 0.4565995617079777, 0.460...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...   548.378277   0.001824  [0.005777934355738146, 0.004077170951106046, 0...
# KIM     [0.6869668053336894, 0.6878333520242234, 0.692...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...   540.785636   0.001849  [0.0008665466905339869, 0.004872605778245109, ...
# WTW     [0.4459214501510574, 0.4364652536117262, 0.428...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...   507.423943   0.001971  [-0.009456196539331163, -0.007748808766249116,...
# UHS     [0.8996845766677712, 0.8926739549205236, 0.889...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...   501.248896   0.001995  [-0.007010621747247647, -0.0027044265023964398...
# VICI    [0.9930128429117181, 0.9925002519388215, 0.991...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...   498.917176   0.002004  [-0.0005125909728965761, -0.001190999073147458...
# SYY     [0.1839621482118717, 0.18527725635431994, 0.18...  [2025-06-30 00:00:00, 2024-06-30 00:00:00, 202...   496.068914   0.002016  [0.0013151081424482292, -0.0024407021453451694...
# ROP     [0.693019093078759, 0.6972061251578232, 0.6986...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...   494.896643   0.002021  [0.004187032079064235, 0.001405141084404704, 0...
# LLY     [0.8131040101947707, 0.7924575300154436, 0.767...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...   440.668959   0.002269  [-0.02064648017932713, -0.024744663793043853, ...
# MTD     [0.6135623718966284, 0.6045539051856647, 0.600...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...   435.711691   0.002295  [-0.00900846671096378, -0.0037883891741443687,...
# ADSK    [0.9270918284129832, 0.9246861924686193, 0.926...  [2025-01-31 00:00:00, 2024-01-31 00:00:00, 202...   425.143327   0.002352  [-0.0024056359443639375, 0.0013877336053067513...
# DG      [0.29590775781568485, 0.3028828291943093, 0.31...  [2025-01-31 00:00:00, 2024-01-31 00:00:00, 202...   421.033120   0.002375  [0.0069750713786244645, 0.009447486283381823, ...
# INCY    [0.9264126310915004, 0.9309999407411256, 0.939...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...   417.983770   0.002392  [0.004587309649625171, 0.008021485715621668, 0...
# HSIC    [0.31823561903258896, 0.3138828106005349, 0.30...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...   400.387236   0.002498  [-0.004352808432054045, -0.010016280988769277,...
# VRSN    [0.8771028637472711, 0.8678588172259059, 0.859...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...   400.021812   0.002500  [-0.009244046521365235, -0.008710806839212104,...

# %%
GPM_smooth.to_excel("sp500_pricing_power_GPM_smooth.xlsx", index=True)

# %%
# ==========================================
# Upward Trending Gross Margins — strict positive trend version
# ==========================================
# Rewards firms whose gross profit margins show a positive linear trend.
# Negative or flat trends are fully excluded from output.
# Standard deviation still reported but does not affect inclusion.

# ---------- 0) AUTO-INSTALL DEPENDENCIES ----------
import sys, subprocess, importlib

REQUIRED_PACKAGES = [
    "yfinance",
    "pandas",
    "numpy",
    "lxml",
    "beautifulsoup4",
    "html5lib",
    "requests",
]

def ensure_packages(pkgs):
    for p in pkgs:
        try:
            importlib.import_module(p if p != "beautifulsoup4" else "bs4")
        except ImportError:
            print(f"Installing missing package: {p} …")
            subprocess.check_call([sys.executable, "-m", "pip", "install", p])

ensure_packages(REQUIRED_PACKAGES)

# ---------- 1) IMPORTS ----------
import re, time, math, numpy as np, pandas as pd, requests, yfinance as yf
from typing import Optional, List, Dict, Tuple

# ---------- 2) CONFIG ----------
MAX_YEARS = 5
SLEEP_SEC = 0.5
RETRY_N = 2
EXCLUDE_FINANCIALS = True
EXCLUDE_YOUNG_YEARS = 0
OUTPUT_CSV = "sp500_pricing_power_uptrend_positive_only.csv"

UA = (
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
    "AppleWebKit/537.36 (KHTML, like Gecko) "
    "Chrome/127.0.0.1 Safari/537.36"
)

# ---------- 3) S&P500 FETCHERS ----------
def read_html_with_headers(url: str, **kwargs) -> List[pd.DataFrame]:
    storage_options = kwargs.pop("storage_options", {}) or {}
    storage_options.setdefault("User-Agent", UA)
    return pd.read_html(url, storage_options=storage_options, **kwargs)

def fetch_sp500_from_wikipedia() -> pd.DataFrame:
    wiki = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
    try:
        tables = read_html_with_headers(wiki)
        if tables:
            return tables[0]
    except Exception:
        pass
    with requests.Session() as s:
        s.headers.update({"User-Agent": UA})
        r = s.get(wiki, timeout=20)
        r.raise_for_status()
        tables = pd.read_html(r.text)
        if tables:
            return tables[0]
    raise RuntimeError("Wikipedia fetch failed.")

def fetch_sp500_from_fallback() -> pd.DataFrame:
    url_csv = "https://raw.githubusercontent.com/datasets/s-and-p-500-companies/master/data/constituents.csv"
    import io
    with requests.Session() as s:
        s.headers.update({"User-Agent": UA})
        r = s.get(url_csv, timeout=20)
        r.raise_for_status()
        return pd.read_csv(io.StringIO(r.text))

def get_sp500_table() -> pd.DataFrame:
    try:
        df = fetch_sp500_from_wikipedia()
    except Exception:
        df = fetch_sp500_from_fallback()
    df.columns = [c.strip() for c in df.columns]
    mapper = {
        "Symbol": "Ticker",
        "Security": "Full Name",
        "GICS Sector": "Sector",
        "GICS Sub-Industry": "Sub-Industry",
        "Date added": "Date Added",
        "Founded": "Founded (Wiki)"
    }
    for old, new in mapper.items():
        if old in df.columns:
            df = df.rename(columns={old: new})
    for col in ["Sector", "Sub-Industry", "Date Added", "Founded (Wiki)"]:
        if col not in df.columns:
            df[col] = np.nan
    return df[["Ticker", "Full Name", "Sector", "Sub-Industry", "Date Added", "Founded (Wiki)"]].copy()

# ---------- 4) HELPERS ----------
def yf_ticker(symbol: str) -> str:
    return str(symbol).replace(".", "-").strip()

def find_label(idx: pd.Index, candidates: List[str]) -> Optional[str]:
    s = idx.to_series().astype(str)
    for cand in candidates:
        mask = s.str.contains(cand, case=False, na=False)
        if mask.any():
            return s[mask].index[0]
    return None

def parse_year(x) -> Optional[int]:
    if pd.isna(x): return None
    m = re.search(r"(18|19|20)\d{2}", str(x))
    return int(m.group(0)) if m else None

def get_income_stmt(tkr: yf.Ticker) -> Optional[pd.DataFrame]:
    for attr in ("income_stmt", "financials"):
        df = getattr(tkr, attr, None)
        if isinstance(df, pd.DataFrame) and not df.empty:
            return df
    try:
        df = tkr.get_income_stmt()
        if isinstance(df, pd.DataFrame) and not df.empty:
            return df
    except Exception:
        pass
    return None

def safe_get_info_item(tkr: yf.Ticker, key: str):
    try:
        info = tkr.info
        return info.get(key, np.nan) if isinstance(info, dict) else np.nan
    except Exception:
        return np.nan

# ---------- 5) METRIC: strict positive trend ----------
def uptrend_score_positive_only(margins: List[float]) -> Tuple[float, float, float, float]:
    """
    Only accepts firms with a positive slope in gross margins.
    Returns (score, slope, resid_std, r2). Score = slope / (resid_std + 1e-6)
    Negative slopes → excluded later (None).
    """
    y = np.array(margins, dtype=float)
    n = len(y)
    if n < 3:
        return np.nan, np.nan, np.nan, np.nan
    t = np.arange(n, dtype=float)
    b, a = np.polyfit(t, y, 1)
    y_hat = a + b * t
    resid = y - y_hat
    resid_std = float(np.std(resid, ddof=0))
    ss_res = float(np.sum(resid**2))
    ss_tot = float(np.sum((y - y.mean())**2)) if n > 1 else 0.0
    r2 = 1.0 - ss_res/ss_tot if ss_tot > 0 else 1.0
    slope = float(b)
    if slope <= 0:  # strictly enforce positive trend
        return np.nan, slope, resid_std, r2
    score = slope / (resid_std + 1e-6)
    return score, slope, resid_std, r2

# ---------- 6) COLLECTOR ----------
def collect_uptrend_pricing_power(row: pd.Series, n_years:int=MAX_YEARS) -> Optional[Dict]:
    ticker = row["YF Ticker"]
    orig_ticker = row["Ticker"]
    last_err = None

    for attempt in range(1, RETRY_N + 2):
        try:
            t = yf.Ticker(ticker)
            fin = get_income_stmt(t)
            if fin is None or fin.empty:
                last_err = "no financials"
                break

            rev_label  = find_label(fin.index, ["total revenue", "revenue"])
            cogs_label = find_label(fin.index, ["cost of revenue", "cost of goods sold", "cost revenue"])
            if not rev_label or not cogs_label:
                last_err = f"missing rows → rev={rev_label}, cogs={cogs_label}"
                break

            revenue = fin.loc[rev_label].dropna()
            cogs    = fin.loc[cogs_label].dropna()
            common_cols = [c for c in revenue.index if c in cogs.index]
            if not common_cols:
                last_err = "no overlapping revenue/COGS columns"
                break
            try:
                common_cols = sorted(common_cols, reverse=True)
            except Exception:
                pass

            margins, used_cols = [], []
            for c in common_cols:
                r, cg = revenue[c], cogs[c]
                if pd.notna(r) and pd.notna(cg) and r not in (0, 0.0):
                    gm = (r - cg) / r
                    if isinstance(gm, (int, float)) and math.isfinite(gm) and -5.0 < gm < 5.0:
                        margins.append(float(gm))
                        used_cols.append(str(c))
                if len(margins) >= n_years:
                    break
            if len(margins) < 3:
                last_err = f"only {len(margins)} margins"
                break

            score, slope, resid_std, r2 = uptrend_score_positive_only(margins)
            if np.isnan(score):  # exclude non-positive slopes
                return None

            founding_year_yf = safe_get_info_item(t, "founded")
            mcap = safe_get_info_item(t, "marketCap")

            return {
                "Ticker": orig_ticker,
                "YF Ticker": ticker,
                "Full Name": row["Full Name"],
                "Sector": row.get("Sector", np.nan),
                "Sub-Industry": row.get("Sub-Industry", np.nan),
                "Date Added": row.get("Date Added", np.nan),
                "Founded (Wiki)": row.get("Founded (Wiki)", np.nan),
                "Founding Year (YF)": founding_year_yf,
                "Market Cap": mcap,
                "Gross Margins (newest→older)": margins,
                "Years Used (labels)": used_cols,
                "Uptrend Slope": slope,
                "Trend Residual Std": resid_std,
                "Trend R^2": r2,
                "Pricing Power (Uptrend)": score,
            }
        except Exception as e:
            last_err = str(e)
        time.sleep(SLEEP_SEC * attempt)

    print(f"  ❌ {orig_ticker}: {last_err}")
    return None

# ---------- 7) PIPELINE ----------
sp500_df = get_sp500_table()
sp500_df["YF Ticker"] = sp500_df["Ticker"].map(yf_ticker)
sp500_df["Founded_Year_Wiki"] = sp500_df["Founded (Wiki)"].apply(parse_year)

if EXCLUDE_FINANCIALS:
    sp500_df = sp500_df[~sp500_df["Sector"].isin({"Financials", "Real Estate"})].copy()

if EXCLUDE_YOUNG_YEARS and "Founded_Year_Wiki" in sp500_df.columns:
    current_year = pd.Timestamp.today().year
    mask_old = sp500_df["Founded_Year_Wiki"].apply(
        lambda y: (isinstance(y, (int, np.integer)) and (current_year - int(y) >= EXCLUDE_YOUNG_YEARS))
    )
    sp500_df = sp500_df[mask_old | sp500_df["Founded_Year_Wiki"].isna()].copy()

results: List[Dict] = []
n = len(sp500_df)
for i, row in sp500_df.reset_index(drop=True).iterrows():
    print(f"Processing {row['Ticker']} ({i+1}/{n}) …")
    rec = collect_uptrend_pricing_power(row)
    if rec:
        results.append(rec)
    time.sleep(SLEEP_SEC)

# ---------- 8) OUTPUT ----------
if results:
    df = pd.DataFrame(results).set_index("Ticker")
    show_cols = [
        "Full Name", "Sector", "Sub-Industry",
        "Founding Year (YF)", "Founded (Wiki)", "Date Added",
        "Market Cap", "Pricing Power (Uptrend)", "Uptrend Slope",
        "Trend Residual Std", "Trend R^2",
        "Gross Margins (newest→older)", "Years Used (labels)"
    ]
    df = df.reindex(columns=show_cols).sort_values("Pricing Power (Uptrend)", ascending=False)
    df.to_csv(OUTPUT_CSV)
    print(f"\n✅ Done! Positive-trend firms saved to {OUTPUT_CSV}\n")
else:
    print("⚠️ No firms with positive uptrends found.")
# Out:
# Processing MMM (1/397) …
# Processing AOS (2/397) …
# Processing ABT (3/397) …
# Processing ABBV (4/397) …
# Processing ACN (5/397) …
# Processing ADBE (6/397) …
# Processing AMD (7/397) …
# Processing AES (8/397) …
# Processing A (9/397) …
# Processing APD (10/397) …
# Processing ABNB (11/397) …
# Processing AKAM (12/397) …
# Processing ALB (13/397) …
# Processing ALGN (14/397) …
# Processing ALLE (15/397) …
# Processing LNT (16/397) …
# Processing GOOGL (17/397) …
# Processing GOOG (18/397) …
# Processing MO (19/397) …
# Processing AMZN (20/397) …
# Processing AMCR (21/397) …
# Processing AEE (22/397) …
# Processing AEP (23/397) …
# Processing AWK (24/397) …
# Processing AME (25/397) …
# Processing AMGN (26/397) …
# Processing APH (27/397) …
# Processing ADI (28/397) …
# Processing APA (29/397) …
# Processing AAPL (30/397) …
# Processing AMAT (31/397) …
# Processing APP (32/397) …
# Processing APTV (33/397) …
# Processing ADM (34/397) …
# Processing ANET (35/397) …
# Processing T (36/397) …
# Processing ATO (37/397) …
# Processing ADSK (38/397) …
# Processing ADP (39/397) …
# Processing AZO (40/397) …
# Processing AVY (41/397) …
# Processing AXON (42/397) …
# Processing BKR (43/397) …
# Processing BALL (44/397) …
# Processing BAX (45/397) …
# Processing BDX (46/397) …
# Processing BBY (47/397) …
# Processing TECH (48/397) …
# Processing BIIB (49/397) …
# Processing BA (50/397) …
# Processing BKNG (51/397) …
#   ❌ BKNG: missing rows → rev=Total Revenue, cogs=None
# Processing BSX (52/397) …
# Processing BMY (53/397) …
# Processing AVGO (54/397) …
# Processing BR (55/397) …
# Processing BF.B (56/397) …
# Processing BLDR (57/397) …
# Processing BG (58/397) …
# Processing CHRW (59/397) …
# Processing CDNS (60/397) …
# Processing CPB (61/397) …
# Processing CAH (62/397) …
# Processing KMX (63/397) …
# Processing CCL (64/397) …
# Processing CARR (65/397) …
# Processing CAT (66/397) …
# Processing CDW (67/397) …
# Processing COR (68/397) …
# Processing CNC (69/397) …
# Processing CNP (70/397) …
# Processing CF (71/397) …
# Processing CRL (72/397) …
# Processing CHTR (73/397) …
# Processing CVX (74/397) …
# Processing CMG (75/397) …
# Processing CHD (76/397) …
# Processing CI (77/397) …
#   ❌ CI: missing rows → rev=Total Revenue, cogs=None
# Processing CTAS (78/397) …
# Processing CSCO (79/397) …
# Processing CLX (80/397) …
# Processing CMS (81/397) …
# Processing KO (82/397) …
# Processing CTSH (83/397) …
# Processing CL (84/397) …
# Processing CMCSA (85/397) …
# Processing CAG (86/397) …
# Processing COP (87/397) …
# Processing ED (88/397) …
# Processing STZ (89/397) …
# Processing CEG (90/397) …
# Processing COO (91/397) …
# Processing CPRT (92/397) …
# Processing GLW (93/397) …
# Processing CTVA (94/397) …
# Processing COST (95/397) …
# Processing CTRA (96/397) …
# Processing CRWD (97/397) …
# Processing CSX (98/397) …
# Processing CMI (99/397) …
# Processing CVS (100/397) …
# Processing DHR (101/397) …
# Processing DRI (102/397) …
# Processing DDOG (103/397) …
# Processing DVA (104/397) …
# Processing DAY (105/397) …
# Processing DECK (106/397) …
# Processing DE (107/397) …
# Processing DELL (108/397) …
# Processing DAL (109/397) …
# Processing DVN (110/397) …
# Processing DXCM (111/397) …
# Processing FANG (112/397) …
# Processing DG (113/397) …
# Processing DLTR (114/397) …
# Processing D (115/397) …
# Processing DPZ (116/397) …
# Processing DASH (117/397) …
# Processing DOV (118/397) …
# Processing DOW (119/397) …
# Processing DHI (120/397) …
# Processing DTE (121/397) …
# Processing DUK (122/397) …
# Processing DD (123/397) …
# Processing EMN (124/397) …
# Processing ETN (125/397) …
# Processing EBAY (126/397) …
# Processing ECL (127/397) …
# Processing EIX (128/397) …
# Processing EW (129/397) …
# Processing EA (130/397) …
# Processing ELV (131/397) …
#   ❌ ELV: missing rows → rev=Total Revenue, cogs=None
# Processing EME (132/397) …
# Processing EMR (133/397) …
# Processing ETR (134/397) …
# Processing EOG (135/397) …
# Processing EPAM (136/397) …
# Processing EQT (137/397) …
# Processing EFX (138/397) …
# Processing EL (139/397) …
# Processing EVRG (140/397) …
# Processing ES (141/397) …
# Processing EXC (142/397) …
# Processing EXE (143/397) …
# Processing EXPE (144/397) …
# Processing EXPD (145/397) …
# Processing XOM (146/397) …
# Processing FFIV (147/397) …
# Processing FICO (148/397) …
# Processing FAST (149/397) …
# Processing FDX (150/397) …
# Processing FSLR (151/397) …
# Processing FE (152/397) …
# Processing F (153/397) …
# Processing FTNT (154/397) …
# Processing FTV (155/397) …
# Processing FOXA (156/397) …
#   ❌ FOXA: missing rows → rev=Total Revenue, cogs=None
# Processing FOX (157/397) …
#   ❌ FOX: missing rows → rev=Total Revenue, cogs=None
# Processing FCX (158/397) …
# Processing GRMN (159/397) …
# Processing IT (160/397) …
# Processing GE (161/397) …
# Processing GEHC (162/397) …
# Processing GEV (163/397) …
# Processing GEN (164/397) …
# Processing GNRC (165/397) …
# Processing GD (166/397) …
# Processing GIS (167/397) …
# Processing GM (168/397) …
# Processing GPC (169/397) …
# Processing GILD (170/397) …
# Processing GDDY (171/397) …
# Processing HAL (172/397) …
# Processing HAS (173/397) …
# Processing HCA (174/397) …
# Processing HSIC (175/397) …
# Processing HSY (176/397) …
# Processing HPE (177/397) …
# Processing HLT (178/397) …
# Processing HOLX (179/397) …
# Processing HD (180/397) …
# Processing HON (181/397) …
# Processing HRL (182/397) …
# Processing HWM (183/397) …
# Processing HPQ (184/397) …
# Processing HUBB (185/397) …
# Processing HUM (186/397) …
#   ❌ HUM: missing rows → rev=Total Revenue, cogs=None
# Processing HII (187/397) …
# Processing IBM (188/397) …
# Processing IEX (189/397) …
# Processing IDXX (190/397) …
# Processing ITW (191/397) …
# Processing INCY (192/397) …
# Processing IR (193/397) …
# Processing PODD (194/397) …
# Processing INTC (195/397) …
# Processing IFF (196/397) …
# Processing IP (197/397) …
# Processing IPG (198/397) …
# Processing INTU (199/397) …
# Processing ISRG (200/397) …
# Processing IQV (201/397) …
# Processing JBHT (202/397) …
# Processing JBL (203/397) …
# Processing J (204/397) …
# Processing JNJ (205/397) …
# Processing JCI (206/397) …
# Processing K (207/397) …
# Processing KVUE (208/397) …
# Processing KDP (209/397) …
# Processing KEYS (210/397) …
# Processing KMB (211/397) …
# Processing KMI (212/397) …
# Processing KLAC (213/397) …
# Processing KHC (214/397) …
# Processing KR (215/397) …
# Processing LHX (216/397) …
# Processing LH (217/397) …
# Processing LRCX (218/397) …
# Processing LW (219/397) …
# Processing LVS (220/397) …
# Processing LDOS (221/397) …
# Processing LEN (222/397) …
# Processing LII (223/397) …
# Processing LLY (224/397) …
# Processing LIN (225/397) …
# Processing LYV (226/397) …
# Processing LKQ (227/397) …
# Processing LMT (228/397) …
# Processing LOW (229/397) …
# Processing LULU (230/397) …
# Processing LYB (231/397) …
# Processing MPC (232/397) …
# Processing MAR (233/397) …
# Processing MLM (234/397) …
# Processing MAS (235/397) …
# Processing MTCH (236/397) …
# Processing MKC (237/397) …
# Processing MCD (238/397) …
# Processing MCK (239/397) …
# Processing MDT (240/397) …
# Processing MRK (241/397) …
# Processing META (242/397) …
# Processing MTD (243/397) …
# Processing MGM (244/397) …
# Processing MCHP (245/397) …
# Processing MU (246/397) …
# Processing MSFT (247/397) …
# Processing MRNA (248/397) …
# Processing MHK (249/397) …
# Processing MOH (250/397) …
# Processing TAP (251/397) …
# Processing MDLZ (252/397) …
# Processing MPWR (253/397) …
# Processing MNST (254/397) …
# Processing MOS (255/397) …
# Processing MSI (256/397) …
# Processing NTAP (257/397) …
# Processing NFLX (258/397) …
# Processing NEM (259/397) …
# Processing NWSA (260/397) …
#   ❌ NWSA: missing rows → rev=Total Revenue, cogs=None
# Processing NWS (261/397) …
#   ❌ NWS: missing rows → rev=Total Revenue, cogs=None
# Processing NEE (262/397) …
# Processing NKE (263/397) …
# Processing NI (264/397) …
# Processing NDSN (265/397) …
# Processing NSC (266/397) …
# Processing NOC (267/397) …
# Processing NCLH (268/397) …
# Processing NRG (269/397) …
# Processing NUE (270/397) …
# Processing NVDA (271/397) …
# Processing NVR (272/397) …
# Processing NXPI (273/397) …
# Processing ORLY (274/397) …
# Processing OXY (275/397) …
# Processing ODFL (276/397) …
# Processing OMC (277/397) …
# Processing ON (278/397) …
# Processing OKE (279/397) …
# Processing ORCL (280/397) …
# Processing OTIS (281/397) …
# Processing PCAR (282/397) …
# Processing PKG (283/397) …
# Processing PLTR (284/397) …
# Processing PANW (285/397) …
# Processing PSKY (286/397) …
# Processing PH (287/397) …
# Processing PAYX (288/397) …
# Processing PAYC (289/397) …
# Processing PNR (290/397) …
# Processing PEP (291/397) …
# Processing PFE (292/397) …
# Processing PCG (293/397) …
# Processing PM (294/397) …
# Processing PSX (295/397) …
# Processing PNW (296/397) …
# Processing POOL (297/397) …
# Processing PPG (298/397) …
# Processing PPL (299/397) …
# Processing PG (300/397) …
# Processing PEG (301/397) …
# Processing PTC (302/397) …
# Processing PHM (303/397) …
# Processing PWR (304/397) …
# Processing QCOM (305/397) …
# Processing DGX (306/397) …
# Processing RL (307/397) …
# Processing RTX (308/397) …
# Processing REGN (309/397) …
# Processing RSG (310/397) …
# Processing RMD (311/397) …
# Processing RVTY (312/397) …
# Processing ROK (313/397) …
# Processing ROL (314/397) …
# Processing ROP (315/397) …
# Processing ROST (316/397) …
# Processing RCL (317/397) …
# Processing CRM (318/397) …
# Processing SLB (319/397) …
# Processing STX (320/397) …
# Processing SRE (321/397) …
# Processing NOW (322/397) …
# Processing SHW (323/397) …
# Processing SWKS (324/397) …
# Processing SJM (325/397) …
# Processing SW (326/397) …
# Processing SNA (327/397) …
# Processing SOLV (328/397) …
# Processing SO (329/397) …
# Processing LUV (330/397) …
# Processing SWK (331/397) …
# Processing SBUX (332/397) …
# Processing STLD (333/397) …
# Processing STE (334/397) …
# Processing SYK (335/397) …
# Processing SMCI (336/397) …
# Processing SNPS (337/397) …
# Processing SYY (338/397) …
# Processing TMUS (339/397) …
# Processing TTWO (340/397) …
# Processing TPR (341/397) …
# Processing TRGP (342/397) …
# Processing TGT (343/397) …
# Processing TEL (344/397) …
# Processing TDY (345/397) …
# Processing TER (346/397) …
# Processing TSLA (347/397) …
# Processing TXN (348/397) …
# Processing TPL (349/397) …
# Processing TXT (350/397) …
# Processing TMO (351/397) …
# Processing TJX (352/397) …
# Processing TKO (353/397) …
# Processing TTD (354/397) …
# Processing TSCO (355/397) …
# Processing TT (356/397) …
# Processing TDG (357/397) …
# Processing TRMB (358/397) …
# Processing TYL (359/397) …
# Processing TSN (360/397) …
# Processing UBER (361/397) …
# Processing ULTA (362/397) …
# Processing UNP (363/397) …
# Processing UAL (364/397) …
# Processing UPS (365/397) …
# Processing URI (366/397) …
# Processing UNH (367/397) …
# Processing UHS (368/397) …
# Processing VLO (369/397) …
# Processing VLTO (370/397) …
# Processing VRSN (371/397) …
# Processing VRSK (372/397) …
# Processing VZ (373/397) …
# Processing VRTX (374/397) …
# Processing VTRS (375/397) …
# Processing VST (376/397) …
# Processing VMC (377/397) …
# Processing GWW (378/397) …
# Processing WAB (379/397) …
# Processing WMT (380/397) …
# Processing DIS (381/397) …
# Processing WBD (382/397) …
# Processing WM (383/397) …
# Processing WAT (384/397) …
# Processing WEC (385/397) …
# Processing WST (386/397) …
# Processing WDC (387/397) …
# Processing WSM (388/397) …
# Processing WMB (389/397) …
# Processing WDAY (390/397) …
# Processing WYNN (391/397) …
# Processing XEL (392/397) …
# Processing XYL (393/397) …
# Processing YUM (394/397) …
# Processing ZBRA (395/397) …
# Processing ZBH (396/397) …
# Processing ZTS (397/397) …
#
# ✅ Done! Positive-trend firms saved to sp500_pricing_power_uptrend_positive_only.csv

# %%
df = GPM_uptrend
GPM_uptrend.to_excel("sp500_pricing_power_GPM_uptrend.xlsx", index=True)

# %%
GPM_uptrend.head(500
                 )
# Out:
#                    Full Name                  Sector                                  Sub-Industry  Founding Year (YF) Founded (Wiki)  Date Added    Market Cap  Pricing Power (Uptrend)  \
# Ticker
# MCK     McKesson Corporation             Health Care                      Health Care Distributors                 NaN           1833  1999-01-13   94973698048                10.328353
# CVS               CVS Health             Health Care                          Health Care Services                 NaN           1996  1957-03-04   98802630656                 8.358944
# F         Ford Motor Company  Consumer Discretionary                      Automobile Manufacturers                 NaN           1903  1957-03-04   45410205696                 6.844903
# DG            Dollar General        Consumer Staples           Consumer Staples Merchandise Retail                 NaN           1939  2012-12-03   21838921728                 5.599267
# INCY                  Incyte             Health Care                                 Biotechnology                 NaN           1991  2017-02-28   16364141568                 5.269908
# ...                      ...                     ...                                           ...                 ...            ...         ...           ...                      ...
# AMAT       Applied Materials  Information Technology           Semiconductor Materials & Equipment                 NaN           1967  1995-03-16  167255080960                 0.000000
# APP                 AppLovin  Information Technology                          Application Software                 NaN           2012  2025-09-22  192765247488                 0.000000
# AOS              A. O. Smith             Industrials                             Building Products                 NaN           1916  2017-07-26    9493779456                 0.000000
# ZTS                   Zoetis             Health Care                               Pharmaceuticals                 NaN           1952  2013-06-21   62537621504                 0.000000
# GWW           W. W. Grainger             Industrials  Industrial Machinery & Supplies & Components                 NaN           1927  1981-06-30   45323919360                 0.000000
#
#         Uptrend Slope (pp/year)  Trend Residual Std  Trend R^2                       Gross Margins (newest→older)                                Years Used (labels)
# Ticker
# MCK                    0.004104            0.000396   0.992594  [0.0371061492657032, 0.041521147366410854, 0.0...  [2025-03-31 00:00:00, 2024-03-31 00:00:00, 202...
# CVS                    0.013853            0.001656   0.988694  [0.13787489035940656, 0.15213709136442913, 0.1...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...
# F                      0.012711            0.001856   0.983230  [0.08381984085798305, 0.09171864624186253, 0.1...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...
# DG                     0.006967            0.001243   0.975157  [0.29590775781568485, 0.3028828291943093, 0.31...  [2025-01-31 00:00:00, 2024-01-31 00:00:00, 202...
# INCY                   0.007710            0.001462   0.972038  [0.9264126310915004, 0.9309999407411256, 0.939...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...
# ...                         ...                 ...        ...                                                ...                                                ...
# AMAT                  -0.000595            0.003946   0.027625  [0.47457315278186635, 0.4670211562393936, 0.46...  [2024-10-31 00:00:00, 2023-10-31 00:00:00, 202...
# APP                   -0.044124            0.051109   0.482312  [0.7522309294392651, 0.6773795516232132, 0.554...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...
# AOS                   -0.006402            0.009730   0.351092  [0.38136769597443754, 0.3853820598006645, 0.35...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...
# ZTS                   -0.001691            0.002765   0.318572  [0.7447061365600691, 0.7402855805243446, 0.735...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...
# GWW                   -0.010365            0.005554   0.813197  [0.39363932898415654, 0.39422259983007646, 0.3...  [2024-12-31 00:00:00, 2023-12-31 00:00:00, 202...
#
# [389 rows x 13 columns]
